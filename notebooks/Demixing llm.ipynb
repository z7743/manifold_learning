# %%
from manifold_learning import IMD
import numpy as np
from FastCCM import CCM, CCM_utils
from manifold_learning.utils import utils
from manifold_learning.data.data_loader import load_csv_dataset
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from manifold_learning import imd_nd_smap
import importlib
import scipy.cluster.hierarchy as sch
import seaborn as sns
importlib.reload(imd_nd_smap)
importlib.reload(CCM)
# Out:
# <module 'FastCCM.CCM' from '/home/iaroslav/Documents/Python projects/FastCCM/src/FastCCM/CCM.py'>

# %%
from matplotlib.colors import LinearSegmentedColormap

def plot_pairwise_arrows_with_direction_gradient(ax,pairwise_matrix, strength_matrix, points, start_color='blue', end_color='red', steps=100):
    """
    Plots arrows between points based on a pairwise matrix, with arrow color as a gradient
    from start_color to end_color and width determined by connection strength. Points are plotted in black.

    Parameters:
    - pairwise_matrix (ndarray): Boolean matrix indicating direction of connections (True/False).
    - strength_matrix (ndarray): Numeric matrix indicating strength of connections.
    - points (ndarray): Coordinates of points as an (N, 2) array.
    - start_color (str): Color of the arrow's start.
    - end_color (str): Color of the arrow's end.
    - steps (int): Number of gradient segments.

    Returns:
    - None
    """

    # Normalize strength matrix for line width scaling
    min_strength = np.min(strength_matrix[strength_matrix > 0])
    max_strength = np.max(strength_matrix)
    normalize_strength = lambda s: (s - min_strength) / (max_strength - min_strength) + 0.1

    # Plot the points in black
    ax.scatter(points[:, 0], points[:, 1], color='black', s=50, zorder=5)

    # Plot the arrows
    for i in range(pairwise_matrix.shape[0]):
        for j in range(pairwise_matrix.shape[1]):
            if pairwise_matrix[i, j]:  # Check if there's a connection
                start = points[i]
                end = points[j]
                strength = strength_matrix[i, j]
                width = normalize_strength(strength)  # Scale the width based on strength
                gradient_arrow(ax, start, end, start_color, end_color, width, steps)

    # Customize plot
    #ax.set_xlim(points[:, 0].min() - 0.5, points[:, 0].max() + 0.5)
    #ax.set_ylim(points[:, 1].min() - 0.5, points[:, 1].max() + 0.5)
    #ax.set_aspect('equal', adjustable='datalim')
    #ax.set_title('Pairwise Connections with Gradient-Colored Arrows and Points')
    plt.grid()
    plt.show()

def gradient_arrow(ax, start, end, start_color, end_color, width, steps):
    """
    Draws a single arrow with a gradient color and adjustable width.

    Parameters:
    - ax: Matplotlib axis object.
    - start (tuple): Starting point (x, y).
    - end (tuple): Ending point (x, y).
    - start_color (str): Start color of the arrow.
    - end_color (str): End color of the arrow.
    - width (float): Width of the arrow lines.
    - steps (int): Number of gradient segments.
    """
    cmap = LinearSegmentedColormap.from_list('gradient', [start_color, end_color])
    for t in np.linspace(0, 1, steps):
        intermediate_start = (1 - t) * np.array(start) + t * np.array(end)
        intermediate_end = (1 - (t + 1 / steps)) * np.array(start) + (t + 1 / steps) * np.array(end)
        ax.plot(
            [intermediate_start[0], intermediate_end[0]],
            [intermediate_start[1], intermediate_end[1]],
            color=cmap(t),
            lw=width*10,
            solid_capstyle='round',
        )

# %%
X = np.load("../src/manifold_learning/data/datasets/llm_data.npy")

# %%
X = StandardScaler().fit_transform(X)

# %%
plt.imshow((observables_train[:].T),aspect="auto",interpolation="nearest")
plt.colorbar()

# %%
plt.plot(np.mean([[np.corrcoef(observables_train[k:,i], observables_train[:-k,i])[1,0] for k in range(1,200)] for i in range(50)],axis=0))

# %%
n_exp = 30
n_comp_list = [2]
models = []
unmixed_train_all = []
unmixed_test_all = []

for n_comp in n_comp_list:
    for exp in range(n_exp):
        A = np.random.normal(0,0.01,(X.shape[1],1000))
        observables = X #@ A
        observables_test = observables[10000:20000]
        observables_train= observables[:10000]

        trainer = imd_nd_smap.IMD_nD_smap(observables.shape[1], embed_dim=10, n_components=n_comp, subtract_corr=False, device="cuda")

        trainer.fit(observables_train, sample_len=170, library_len=700, 
                exclusion_rad=10, theta=5, tp=1, 
                epochs=100, num_batches=32,optimizer="Adagrad", learning_rate=0.01, tp_policy="range",loss_mask_size=3 if n_comp > 3 else None)
        models += [trainer.model]


        unmixed_train = trainer.predict(observables_train)
        unmixed_test = trainer.predict(observables_test)
        unmixed_train_all += [unmixed_train.copy()]
        unmixed_test_all += [unmixed_test.copy()]
# Out:
# Epoch 1/100, Loss: 0.9724
# Epoch 2/100, Loss: 0.9493
# Epoch 3/100, Loss: 0.7973
# Epoch 4/100, Loss: 0.8193
# Epoch 5/100, Loss: 0.6482
# Epoch 6/100, Loss: 0.8015
# Epoch 7/100, Loss: 0.6062
# Epoch 8/100, Loss: 0.7105
# Epoch 9/100, Loss: 0.5528
# Epoch 10/100, Loss: 0.6400
# Epoch 11/100, Loss: 0.4558
# Epoch 12/100, Loss: 0.5853
# Epoch 13/100, Loss: 0.5048
# Epoch 14/100, Loss: 0.5182
# Epoch 15/100, Loss: 0.4532
# Epoch 16/100, Loss: 0.4333
# Epoch 17/100, Loss: 0.4118
# Epoch 18/100, Loss: 0.3765
# Epoch 19/100, Loss: 0.4152
# Epoch 20/100, Loss: 0.3821
# Epoch 21/100, Loss: 0.3751
# Epoch 22/100, Loss: 0.3150
# Epoch 23/100, Loss: 0.3153
# Epoch 24/100, Loss: 0.3624
# Epoch 25/100, Loss: 0.2987
# Epoch 26/100, Loss: 0.3293
# Epoch 27/100, Loss: 0.3027
# Epoch 28/100, Loss: 0.3544
# Epoch 29/100, Loss: 0.3796
# Epoch 30/100, Loss: 0.2857
# Epoch 31/100, Loss: 0.2644
# Epoch 32/100, Loss: 0.2638
# Epoch 33/100, Loss: 0.2567
# Epoch 34/100, Loss: 0.2735
# Epoch 35/100, Loss: 0.2515
# Epoch 36/100, Loss: 0.2806
# Epoch 37/100, Loss: 0.2639
# Epoch 38/100, Loss: 0.2352
# Epoch 39/100, Loss: 0.2548
# Epoch 40/100, Loss: 0.3109
# Epoch 41/100, Loss: 0.2589
# Epoch 42/100, Loss: 0.2387
# Epoch 43/100, Loss: 0.2180
# Epoch 44/100, Loss: 0.1998
# Epoch 45/100, Loss: 0.1907
# Epoch 46/100, Loss: 0.1861
# Epoch 47/100, Loss: 0.1810
# Epoch 48/100, Loss: 0.1825
# Epoch 49/100, Loss: 0.1938
# Epoch 50/100, Loss: 0.1873
# Epoch 51/100, Loss: 0.1693
# Epoch 52/100, Loss: 0.1692
# Epoch 53/100, Loss: 0.1672
# Epoch 54/100, Loss: 0.1788
# Epoch 55/100, Loss: 0.1788
# Epoch 56/100, Loss: 0.1838
# Epoch 57/100, Loss: 0.2737
# Epoch 58/100, Loss: 0.2585
# Epoch 59/100, Loss: 0.3322
# Epoch 60/100, Loss: 0.2451
# Epoch 61/100, Loss: 0.2654
# Epoch 62/100, Loss: 0.2073
# Epoch 63/100, Loss: 0.2086
# Epoch 64/100, Loss: 0.1927
# Epoch 65/100, Loss: 0.1762
# Epoch 66/100, Loss: 0.1759
# Epoch 67/100, Loss: 0.1865
# Epoch 68/100, Loss: 0.1561
# Epoch 69/100, Loss: 0.1507
# Epoch 70/100, Loss: 0.1492
# Epoch 71/100, Loss: 0.1389
# Epoch 72/100, Loss: 0.1377
# Epoch 73/100, Loss: 0.1347
# Epoch 74/100, Loss: 0.1325
# Epoch 75/100, Loss: 0.1301
# Epoch 76/100, Loss: 0.1299
# Epoch 77/100, Loss: 0.1252
# Epoch 78/100, Loss: 0.1269
# Epoch 79/100, Loss: 0.1242
# Epoch 80/100, Loss: 0.1224
# Epoch 81/100, Loss: 0.1349
# Epoch 82/100, Loss: 0.2140
# Epoch 83/100, Loss: 0.1626
# Epoch 84/100, Loss: 0.1814
# Epoch 85/100, Loss: 0.2345
# Epoch 86/100, Loss: 0.1429
# Epoch 87/100, Loss: 0.1362
# Epoch 88/100, Loss: 0.1462
# Epoch 89/100, Loss: 0.2519
# Epoch 90/100, Loss: 0.1476
# Epoch 91/100, Loss: 0.1614
# Epoch 92/100, Loss: 0.2003
# Epoch 93/100, Loss: 0.1419
# Epoch 94/100, Loss: 0.1317
# Epoch 95/100, Loss: 0.1240
# Epoch 96/100, Loss: 0.1207
# Epoch 97/100, Loss: 0.1178
# Epoch 98/100, Loss: 0.1174
# Epoch 99/100, Loss: 0.1125
# Epoch 100/100, Loss: 0.1143
# Epoch 1/100, Loss: 0.9700
# Epoch 2/100, Loss: 0.9459
# Epoch 3/100, Loss: 0.7975
# Epoch 4/100, Loss: 0.8613
# Epoch 5/100, Loss: 0.7252
# Epoch 6/100, Loss: 0.7546
# Epoch 7/100, Loss: 0.6650
# Epoch 8/100, Loss: 0.6795
# Epoch 9/100, Loss: 0.5602
# Epoch 10/100, Loss: 0.6799
# Epoch 11/100, Loss: 0.4673
# Epoch 12/100, Loss: 0.6130
# Epoch 13/100, Loss: 0.4554
# Epoch 14/100, Loss: 0.5631
# Epoch 15/100, Loss: 0.4021
# Epoch 16/100, Loss: 0.5290
# Epoch 17/100, Loss: 0.4302
# Epoch 18/100, Loss: 0.5003
# Epoch 19/100, Loss: 0.3501
# Epoch 20/100, Loss: 0.3998
# Epoch 21/100, Loss: 0.3540
# Epoch 22/100, Loss: 0.3934
# Epoch 23/100, Loss: 0.3641
# Epoch 24/100, Loss: 0.3089
# Epoch 25/100, Loss: 0.3508
# Epoch 26/100, Loss: 0.3313
# Epoch 27/100, Loss: 0.3154
# Epoch 28/100, Loss: 0.3009
# Epoch 29/100, Loss: 0.3711
# Epoch 30/100, Loss: 0.2974
# Epoch 31/100, Loss: 0.3017
# Epoch 32/100, Loss: 0.3131
# Epoch 33/100, Loss: 0.2737
# Epoch 34/100, Loss: 0.3452
# Epoch 35/100, Loss: 0.2549
# Epoch 36/100, Loss: 0.2628
# Epoch 37/100, Loss: 0.2299
# Epoch 38/100, Loss: 0.2472
# Epoch 39/100, Loss: 0.2123
# Epoch 40/100, Loss: 0.2338
# Epoch 41/100, Loss: 0.2392
# Epoch 42/100, Loss: 0.2003
# Epoch 43/100, Loss: 0.2011
# Epoch 44/100, Loss: 0.2137
# Epoch 45/100, Loss: 0.2019
# Epoch 46/100, Loss: 0.2509
# Epoch 47/100, Loss: 0.1947
# Epoch 48/100, Loss: 0.2015
# Epoch 49/100, Loss: 0.2742
# Epoch 50/100, Loss: 0.3024
# Epoch 51/100, Loss: 0.2187
# Epoch 52/100, Loss: 0.2293
# Epoch 53/100, Loss: 0.2654
# Epoch 54/100, Loss: 0.2361
# Epoch 55/100, Loss: 0.2801
# Epoch 56/100, Loss: 0.2085
# Epoch 57/100, Loss: 0.1916
# Epoch 58/100, Loss: 0.2004
# Epoch 59/100, Loss: 0.2218
# Epoch 60/100, Loss: 0.2245
# Epoch 61/100, Loss: 0.2246
# Epoch 62/100, Loss: 0.1780
# Epoch 63/100, Loss: 0.1793
# Epoch 64/100, Loss: 0.1808
# Epoch 65/100, Loss: 0.1781
# Epoch 66/100, Loss: 0.1642
# Epoch 67/100, Loss: 0.1535
# Epoch 68/100, Loss: 0.1507
# Epoch 69/100, Loss: 0.1431
# Epoch 70/100, Loss: 0.1425
# Epoch 71/100, Loss: 0.1376
# Epoch 72/100, Loss: 0.1380
# Epoch 73/100, Loss: 0.1378
# Epoch 74/100, Loss: 0.1354
# Epoch 75/100, Loss: 0.1287
# Epoch 76/100, Loss: 0.1306
# Epoch 77/100, Loss: 0.1231
# Epoch 78/100, Loss: 0.1255
# Epoch 79/100, Loss: 0.1458
# Epoch 80/100, Loss: 0.2300
# Epoch 81/100, Loss: 0.1618
# Epoch 82/100, Loss: 0.1714
# Epoch 83/100, Loss: 0.2115
# Epoch 84/100, Loss: 0.1889
# Epoch 85/100, Loss: 0.1898
# Epoch 86/100, Loss: 0.1510
# Epoch 87/100, Loss: 0.1576
# Epoch 88/100, Loss: 0.1755
# Epoch 89/100, Loss: 0.1437
# Epoch 90/100, Loss: 0.1366
# Epoch 91/100, Loss: 0.1383
# Epoch 92/100, Loss: 0.1662
# Epoch 93/100, Loss: 0.1829
# Epoch 94/100, Loss: 0.2442
# Epoch 95/100, Loss: 0.1573
# Epoch 96/100, Loss: 0.1500
# Epoch 97/100, Loss: 0.1510
# Epoch 98/100, Loss: 0.1579
# Epoch 99/100, Loss: 0.1577
# Epoch 100/100, Loss: 0.2172
# Epoch 1/100, Loss: 0.9700
# Epoch 2/100, Loss: 0.9535
# Epoch 3/100, Loss: 0.8057
# Epoch 4/100, Loss: 0.8377
# Epoch 5/100, Loss: 0.6836
# Epoch 6/100, Loss: 0.7906
# Epoch 7/100, Loss: 0.6479
# Epoch 8/100, Loss: 0.7022
# Epoch 9/100, Loss: 0.5470
# Epoch 10/100, Loss: 0.6297
# Epoch 11/100, Loss: 0.4906
# Epoch 12/100, Loss: 0.5457
# Epoch 13/100, Loss: 0.4389
# Epoch 14/100, Loss: 0.4703
# Epoch 15/100, Loss: 0.4302
# Epoch 16/100, Loss: 0.4400
# Epoch 17/100, Loss: 0.3901
# Epoch 18/100, Loss: 0.3788
# Epoch 19/100, Loss: 0.3856
# Epoch 20/100, Loss: 0.4224
# Epoch 21/100, Loss: 0.3351
# Epoch 22/100, Loss: 0.3612
# Epoch 23/100, Loss: 0.3708
# Epoch 24/100, Loss: 0.3123
# Epoch 25/100, Loss: 0.3205
# Epoch 26/100, Loss: 0.3490
# Epoch 27/100, Loss: 0.3255
# Epoch 28/100, Loss: 0.3062
# Epoch 29/100, Loss: 0.2942
# Epoch 30/100, Loss: 0.2835
# Epoch 31/100, Loss: 0.2839
# Epoch 32/100, Loss: 0.2671
# Epoch 33/100, Loss: 0.2482
# Epoch 34/100, Loss: 0.2704
# Epoch 35/100, Loss: 0.2208
# Epoch 36/100, Loss: 0.2237
# Epoch 37/100, Loss: 0.2356
# Epoch 38/100, Loss: 0.2199
# Epoch 39/100, Loss: 0.2443
# Epoch 40/100, Loss: 0.2081
# Epoch 41/100, Loss: 0.2113
# Epoch 42/100, Loss: 0.2035
# Epoch 43/100, Loss: 0.2486
# Epoch 44/100, Loss: 0.2504
# Epoch 45/100, Loss: 0.3028
# Epoch 46/100, Loss: 0.2510
# Epoch 47/100, Loss: 0.2178
# Epoch 48/100, Loss: 0.2495
# Epoch 49/100, Loss: 0.2468
# Epoch 50/100, Loss: 0.2292
# Epoch 51/100, Loss: 0.2151
# Epoch 52/100, Loss: 0.2131
# Epoch 53/100, Loss: 0.2411
# Epoch 54/100, Loss: 0.2983
# Epoch 55/100, Loss: 0.2473
# Epoch 56/100, Loss: 0.2182
# Epoch 57/100, Loss: 0.1925
# Epoch 58/100, Loss: 0.1807
# Epoch 59/100, Loss: 0.1826
# Epoch 60/100, Loss: 0.1812
# Epoch 61/100, Loss: 0.1810
# Epoch 62/100, Loss: 0.1657
# Epoch 63/100, Loss: 0.1655
# Epoch 64/100, Loss: 0.1887
# Epoch 65/100, Loss: 0.1754
# Epoch 66/100, Loss: 0.1695
# Epoch 67/100, Loss: 0.1838
# Epoch 68/100, Loss: 0.1829
# Epoch 69/100, Loss: 0.1611
# Epoch 70/100, Loss: 0.1664
# Epoch 71/100, Loss: 0.1573
# Epoch 72/100, Loss: 0.1482
# Epoch 73/100, Loss: 0.1406
# Epoch 74/100, Loss: 0.1397
# Epoch 75/100, Loss: 0.1467
# Epoch 76/100, Loss: 0.1806
# Epoch 77/100, Loss: 0.2978
# Epoch 78/100, Loss: 0.1760
# Epoch 79/100, Loss: 0.1972
# Epoch 80/100, Loss: 0.2173
# Epoch 81/100, Loss: 0.1603
# Epoch 82/100, Loss: 0.1488
# Epoch 83/100, Loss: 0.1439
# Epoch 84/100, Loss: 0.1367
# Epoch 85/100, Loss: 0.1358
# Epoch 86/100, Loss: 0.1294
# Epoch 87/100, Loss: 0.1295
# Epoch 88/100, Loss: 0.1268
# Epoch 89/100, Loss: 0.1272
# Epoch 90/100, Loss: 0.1903
# Epoch 91/100, Loss: 0.1601
# Epoch 92/100, Loss: 0.1571
# Epoch 93/100, Loss: 0.1878
# Epoch 94/100, Loss: 0.1432
# Epoch 95/100, Loss: 0.1573
# Epoch 96/100, Loss: 0.2021
# Epoch 97/100, Loss: 0.1416
# Epoch 98/100, Loss: 0.1541
# Epoch 99/100, Loss: 0.1879
# Epoch 100/100, Loss: 0.1277
# Epoch 1/100, Loss: 0.9680
# Epoch 2/100, Loss: 0.9410
# Epoch 3/100, Loss: 0.8492
# Epoch 4/100, Loss: 0.8191
# Epoch 5/100, Loss: 0.6580
# Epoch 6/100, Loss: 0.8204
# Epoch 7/100, Loss: 0.6774
# Epoch 8/100, Loss: 0.6814
# Epoch 9/100, Loss: 0.6282
# Epoch 10/100, Loss: 0.7013
# Epoch 11/100, Loss: 0.5715
# Epoch 12/100, Loss: 0.6739
# Epoch 13/100, Loss: 0.4631
# Epoch 14/100, Loss: 0.5591
# Epoch 15/100, Loss: 0.4171
# Epoch 16/100, Loss: 0.5113
# Epoch 17/100, Loss: 0.3750
# Epoch 18/100, Loss: 0.3963
# Epoch 19/100, Loss: 0.3395
# Epoch 20/100, Loss: 0.4185
# Epoch 21/100, Loss: 0.3393
# Epoch 22/100, Loss: 0.3601
# Epoch 23/100, Loss: 0.2964
# Epoch 24/100, Loss: 0.3099
# Epoch 25/100, Loss: 0.2992
# Epoch 26/100, Loss: 0.3023
# Epoch 27/100, Loss: 0.2794
# Epoch 28/100, Loss: 0.3852
# Epoch 29/100, Loss: 0.2897
# Epoch 30/100, Loss: 0.2973
# Epoch 31/100, Loss: 0.2476
# Epoch 32/100, Loss: 0.2918
# Epoch 33/100, Loss: 0.2261
# Epoch 34/100, Loss: 0.2724
# Epoch 35/100, Loss: 0.2375
# Epoch 36/100, Loss: 0.2691
# Epoch 37/100, Loss: 0.2332
# Epoch 38/100, Loss: 0.2975
# Epoch 39/100, Loss: 0.2278
# Epoch 40/100, Loss: 0.2541
# Epoch 41/100, Loss: 0.2076
# Epoch 42/100, Loss: 0.2025
# Epoch 43/100, Loss: 0.2165
# Epoch 44/100, Loss: 0.2160
# Epoch 45/100, Loss: 0.2071
# Epoch 46/100, Loss: 0.2016
# Epoch 47/100, Loss: 0.2072
# Epoch 48/100, Loss: 0.1971
# Epoch 49/100, Loss: 0.2013
# Epoch 50/100, Loss: 0.2109
# Epoch 51/100, Loss: 0.1793
# Epoch 52/100, Loss: 0.1911
# Epoch 53/100, Loss: 0.1736
# Epoch 54/100, Loss: 0.1689
# Epoch 55/100, Loss: 0.1688
# Epoch 56/100, Loss: 0.1767
# Epoch 57/100, Loss: 0.1707
# Epoch 58/100, Loss: 0.1968
# Epoch 59/100, Loss: 0.3337
# Epoch 60/100, Loss: 0.2121
# Epoch 61/100, Loss: 0.3245
# Epoch 62/100, Loss: 0.2343
# Epoch 63/100, Loss: 0.1833
# Epoch 64/100, Loss: 0.1737
# Epoch 65/100, Loss: 0.1671
# Epoch 66/100, Loss: 0.1792
# Epoch 67/100, Loss: 0.1850
# Epoch 68/100, Loss: 0.1529
# Epoch 69/100, Loss: 0.1442
# Epoch 70/100, Loss: 0.1530
# Epoch 71/100, Loss: 0.1674
# Epoch 72/100, Loss: 0.1563
# Epoch 73/100, Loss: 0.1449
# Epoch 74/100, Loss: 0.1370
# Epoch 75/100, Loss: 0.1370
# Epoch 76/100, Loss: 0.1298
# Epoch 77/100, Loss: 0.1238
# Epoch 78/100, Loss: 0.1268
# Epoch 79/100, Loss: 0.1214
# Epoch 80/100, Loss: 0.1193
# Epoch 81/100, Loss: 0.1204
# Epoch 82/100, Loss: 0.1144
# Epoch 83/100, Loss: 0.1138
# Epoch 84/100, Loss: 0.1107
# Epoch 85/100, Loss: 0.1115
# Epoch 86/100, Loss: 0.1071
# Epoch 87/100, Loss: 0.1084
# Epoch 88/100, Loss: 0.1042
# Epoch 89/100, Loss: 0.1132
# Epoch 90/100, Loss: 0.2420
# Epoch 91/100, Loss: 0.2849
# Epoch 92/100, Loss: 0.1863
# Epoch 93/100, Loss: 0.1715
# Epoch 94/100, Loss: 0.1941
# Epoch 95/100, Loss: 0.2436
# Epoch 96/100, Loss: 0.3621
# Epoch 97/100, Loss: 0.2027
# Epoch 98/100, Loss: 0.3169
# Epoch 99/100, Loss: 0.2036
# Epoch 100/100, Loss: 0.1940
# Epoch 1/100, Loss: 0.9693
# Epoch 2/100, Loss: 0.9464
# Epoch 3/100, Loss: 0.7551
# Epoch 4/100, Loss: 0.8327
# Epoch 5/100, Loss: 0.7019
# Epoch 6/100, Loss: 0.7197
# Epoch 7/100, Loss: 0.6061
# Epoch 8/100, Loss: 0.6315
# Epoch 9/100, Loss: 0.5807
# Epoch 10/100, Loss: 0.5528
# Epoch 11/100, Loss: 0.5024
# Epoch 12/100, Loss: 0.4819
# Epoch 13/100, Loss: 0.4894
# Epoch 14/100, Loss: 0.4121
# Epoch 15/100, Loss: 0.4197
# Epoch 16/100, Loss: 0.4035
# Epoch 17/100, Loss: 0.4170
# Epoch 18/100, Loss: 0.3556
# Epoch 19/100, Loss: 0.3793
# Epoch 20/100, Loss: 0.3578
# Epoch 21/100, Loss: 0.3420
# Epoch 22/100, Loss: 0.3187
# Epoch 23/100, Loss: 0.3266
# Epoch 24/100, Loss: 0.2927
# Epoch 25/100, Loss: 0.2838
# Epoch 26/100, Loss: 0.2644
# Epoch 27/100, Loss: 0.2647
# Epoch 28/100, Loss: 0.2670
# Epoch 29/100, Loss: 0.2889
# Epoch 30/100, Loss: 0.2873
# Epoch 31/100, Loss: 0.3148
# Epoch 32/100, Loss: 0.2947
# Epoch 33/100, Loss: 0.2691
# Epoch 34/100, Loss: 0.2275
# Epoch 35/100, Loss: 0.2166
# Epoch 36/100, Loss: 0.2063
# Epoch 37/100, Loss: 0.1945
# Epoch 38/100, Loss: 0.1872
# Epoch 39/100, Loss: 0.1817
# Epoch 40/100, Loss: 0.1786
# Epoch 41/100, Loss: 0.1728
# Epoch 42/100, Loss: 0.1807
# Epoch 43/100, Loss: 0.2115
# Epoch 44/100, Loss: 0.2439
# Epoch 45/100, Loss: 0.2023
# Epoch 46/100, Loss: 0.2110
# Epoch 47/100, Loss: 0.2516
# Epoch 48/100, Loss: 0.2177
# Epoch 49/100, Loss: 0.2048
# Epoch 50/100, Loss: 0.2031
# Epoch 51/100, Loss: 0.2427
# Epoch 52/100, Loss: 0.2318
# Epoch 53/100, Loss: 0.2294
# Epoch 54/100, Loss: 0.2343
# Epoch 55/100, Loss: 0.1982
# Epoch 56/100, Loss: 0.1968
# Epoch 57/100, Loss: 0.2110
# Epoch 58/100, Loss: 0.2006
# Epoch 59/100, Loss: 0.1665
# Epoch 60/100, Loss: 0.1613
# Epoch 61/100, Loss: 0.1548
# Epoch 62/100, Loss: 0.1482
# Epoch 63/100, Loss: 0.1492
# Epoch 64/100, Loss: 0.1471
# Epoch 65/100, Loss: 0.1409
# Epoch 66/100, Loss: 0.1417
# Epoch 67/100, Loss: 0.1402
# Epoch 68/100, Loss: 0.1375
# Epoch 69/100, Loss: 0.1380
# Epoch 70/100, Loss: 0.1748
# Epoch 71/100, Loss: 0.3108
# Epoch 72/100, Loss: 0.1905
# Epoch 73/100, Loss: 0.2558
# Epoch 74/100, Loss: 0.2087
# Epoch 75/100, Loss: 0.2569
# Epoch 76/100, Loss: 0.1735
# Epoch 77/100, Loss: 0.1550
# Epoch 78/100, Loss: 0.1454
# Epoch 79/100, Loss: 0.1392
# Epoch 80/100, Loss: 0.1370
# Epoch 81/100, Loss: 0.1337
# Epoch 82/100, Loss: 0.1335
# Epoch 83/100, Loss: 0.1322
# Epoch 84/100, Loss: 0.1330
# Epoch 85/100, Loss: 0.1278
# Epoch 86/100, Loss: 0.1281
# Epoch 87/100, Loss: 0.1546
# Epoch 88/100, Loss: 0.1678
# Epoch 89/100, Loss: 0.2206
# Epoch 90/100, Loss: 0.1960
# Epoch 91/100, Loss: 0.1484
# Epoch 92/100, Loss: 0.1353
# Epoch 93/100, Loss: 0.1367
# Epoch 94/100, Loss: 0.1257
# Epoch 95/100, Loss: 0.1289
# Epoch 96/100, Loss: 0.1298
# Epoch 97/100, Loss: 0.1685
# Epoch 98/100, Loss: 0.2169
# Epoch 99/100, Loss: 0.1664
# Epoch 100/100, Loss: 0.2355
# Epoch 1/100, Loss: 0.9741
# Epoch 2/100, Loss: 0.9508
# Epoch 3/100, Loss: 0.8237
# Epoch 4/100, Loss: 0.8406
# Epoch 5/100, Loss: 0.7208
# Epoch 6/100, Loss: 0.7971
# Epoch 7/100, Loss: 0.5749
# Epoch 8/100, Loss: 0.7651
# Epoch 9/100, Loss: 0.5611
# Epoch 10/100, Loss: 0.6791
# Epoch 11/100, Loss: 0.4822
# Epoch 12/100, Loss: 0.6291
# Epoch 13/100, Loss: 0.4601
# Epoch 14/100, Loss: 0.5491
# Epoch 15/100, Loss: 0.4313
# Epoch 16/100, Loss: 0.4889
# Epoch 17/100, Loss: 0.4124
# Epoch 18/100, Loss: 0.4923
# Epoch 19/100, Loss: 0.4393
# Epoch 20/100, Loss: 0.4223
# Epoch 21/100, Loss: 0.3627
# Epoch 22/100, Loss: 0.3665
# Epoch 23/100, Loss: 0.4140
# Epoch 24/100, Loss: 0.2888
# Epoch 25/100, Loss: 0.2778
# Epoch 26/100, Loss: 0.2765
# Epoch 27/100, Loss: 0.2798
# Epoch 28/100, Loss: 0.2501
# Epoch 29/100, Loss: 0.2557
# Epoch 30/100, Loss: 0.2401
# Epoch 31/100, Loss: 0.2463
# Epoch 32/100, Loss: 0.2432
# Epoch 33/100, Loss: 0.2111
# Epoch 34/100, Loss: 0.2060
# Epoch 35/100, Loss: 0.2256
# Epoch 36/100, Loss: 0.2544
# Epoch 37/100, Loss: 0.2644
# Epoch 38/100, Loss: 0.2156
# Epoch 39/100, Loss: 0.2166
# Epoch 40/100, Loss: 0.2576
# Epoch 41/100, Loss: 0.2886
# Epoch 42/100, Loss: 0.2647
# Epoch 43/100, Loss: 0.2286
# Epoch 44/100, Loss: 0.2072
# Epoch 45/100, Loss: 0.2358
# Epoch 46/100, Loss: 0.2505
# Epoch 47/100, Loss: 0.2162
# Epoch 48/100, Loss: 0.2067
# Epoch 49/100, Loss: 0.2136
# Epoch 50/100, Loss: 0.2025
# Epoch 51/100, Loss: 0.1875
# Epoch 52/100, Loss: 0.1723
# Epoch 53/100, Loss: 0.1757
# Epoch 54/100, Loss: 0.1689
# Epoch 55/100, Loss: 0.1596
# Epoch 56/100, Loss: 0.1543
# Epoch 57/100, Loss: 0.1549
# Epoch 58/100, Loss: 0.1454
# Epoch 59/100, Loss: 0.1465
# Epoch 60/100, Loss: 0.1383
# Epoch 61/100, Loss: 0.1348
# Epoch 62/100, Loss: 0.1301
# Epoch 63/100, Loss: 0.1311
# Epoch 64/100, Loss: 0.1294
# Epoch 65/100, Loss: 0.1301
# Epoch 66/100, Loss: 0.1280
# Epoch 67/100, Loss: 0.1253
# Epoch 68/100, Loss: 0.1210
# Epoch 69/100, Loss: 0.1271
# Epoch 70/100, Loss: 0.1811
# Epoch 71/100, Loss: 0.2907
# Epoch 72/100, Loss: 0.2024
# Epoch 73/100, Loss: 0.1878
# Epoch 74/100, Loss: 0.2594
# Epoch 75/100, Loss: 0.2430
# Epoch 76/100, Loss: 0.1784
# Epoch 77/100, Loss: 0.1892
# Epoch 78/100, Loss: 0.1840
# Epoch 79/100, Loss: 0.1781
# Epoch 80/100, Loss: 0.1681
# Epoch 81/100, Loss: 0.1787
# Epoch 82/100, Loss: 0.1586
# Epoch 83/100, Loss: 0.1520
# Epoch 84/100, Loss: 0.1495
# Epoch 85/100, Loss: 0.1329
# Epoch 86/100, Loss: 0.1386
# Epoch 87/100, Loss: 0.1278
# Epoch 88/100, Loss: 0.1269
# Epoch 89/100, Loss: 0.1164
# Epoch 90/100, Loss: 0.1153
# Epoch 91/100, Loss: 0.1151
# Epoch 92/100, Loss: 0.1140
# Epoch 93/100, Loss: 0.1161
# Epoch 94/100, Loss: 0.1092
# Epoch 95/100, Loss: 0.1096
# Epoch 96/100, Loss: 0.1077
# Epoch 97/100, Loss: 0.1057
# Epoch 98/100, Loss: 0.1034
# Epoch 99/100, Loss: 0.1037
# Epoch 100/100, Loss: 0.0993
# Epoch 1/100, Loss: 0.9735
# Epoch 2/100, Loss: 0.9468
# Epoch 3/100, Loss: 0.8062
# Epoch 4/100, Loss: 0.8407
# Epoch 5/100, Loss: 0.6682
# Epoch 6/100, Loss: 0.7234
# Epoch 7/100, Loss: 0.6012
# Epoch 8/100, Loss: 0.6682
# Epoch 9/100, Loss: 0.5243
# Epoch 10/100, Loss: 0.6056
# Epoch 11/100, Loss: 0.4780
# Epoch 12/100, Loss: 0.5056
# Epoch 13/100, Loss: 0.4241
# Epoch 14/100, Loss: 0.4374
# Epoch 15/100, Loss: 0.4320
# Epoch 16/100, Loss: 0.4010
# Epoch 17/100, Loss: 0.4625
# Epoch 18/100, Loss: 0.3687
# Epoch 19/100, Loss: 0.3562
# Epoch 20/100, Loss: 0.3309
# Epoch 21/100, Loss: 0.3648
# Epoch 22/100, Loss: 0.3478
# Epoch 23/100, Loss: 0.3100
# Epoch 24/100, Loss: 0.3120
# Epoch 25/100, Loss: 0.3451
# Epoch 26/100, Loss: 0.3228
# Epoch 27/100, Loss: 0.3124
# Epoch 28/100, Loss: 0.2749
# Epoch 29/100, Loss: 0.2663
# Epoch 30/100, Loss: 0.2748
# Epoch 31/100, Loss: 0.2725
# Epoch 32/100, Loss: 0.2456
# Epoch 33/100, Loss: 0.2327
# Epoch 34/100, Loss: 0.2248
# Epoch 35/100, Loss: 0.2330
# Epoch 36/100, Loss: 0.2602
# Epoch 37/100, Loss: 0.2309
# Epoch 38/100, Loss: 0.2149
# Epoch 39/100, Loss: 0.2006
# Epoch 40/100, Loss: 0.2057
# Epoch 41/100, Loss: 0.1968
# Epoch 42/100, Loss: 0.2165
# Epoch 43/100, Loss: 0.2839
# Epoch 44/100, Loss: 0.2842
# Epoch 45/100, Loss: 0.2933
# Epoch 46/100, Loss: 0.2162
# Epoch 47/100, Loss: 0.2112
# Epoch 48/100, Loss: 0.2121
# Epoch 49/100, Loss: 0.2013
# Epoch 50/100, Loss: 0.1898
# Epoch 51/100, Loss: 0.1823
# Epoch 52/100, Loss: 0.1688
# Epoch 53/100, Loss: 0.1596
# Epoch 54/100, Loss: 0.1535
# Epoch 55/100, Loss: 0.1528
# Epoch 56/100, Loss: 0.1503
# Epoch 57/100, Loss: 0.1476
# Epoch 58/100, Loss: 0.1484
# Epoch 59/100, Loss: 0.1527
# Epoch 60/100, Loss: 0.1846
# Epoch 61/100, Loss: 0.1666
# Epoch 62/100, Loss: 0.1778
# Epoch 63/100, Loss: 0.2292
# Epoch 64/100, Loss: 0.1532
# Epoch 65/100, Loss: 0.1529
# Epoch 66/100, Loss: 0.1464
# Epoch 67/100, Loss: 0.1456
# Epoch 68/100, Loss: 0.1845
# Epoch 69/100, Loss: 0.2374
# Epoch 70/100, Loss: 0.1594
# Epoch 71/100, Loss: 0.2142
# Epoch 72/100, Loss: 0.2296
# Epoch 73/100, Loss: 0.1970
# Epoch 74/100, Loss: 0.2385
# Epoch 75/100, Loss: 0.1611
# Epoch 76/100, Loss: 0.1876
# Epoch 77/100, Loss: 0.1495
# Epoch 78/100, Loss: 0.1358
# Epoch 79/100, Loss: 0.1323
# Epoch 80/100, Loss: 0.1282
# Epoch 81/100, Loss: 0.1382
# Epoch 82/100, Loss: 0.1621
# Epoch 83/100, Loss: 0.1495
# Epoch 84/100, Loss: 0.1721
# Epoch 85/100, Loss: 0.2022
# Epoch 86/100, Loss: 0.1715
# Epoch 87/100, Loss: 0.1764
# Epoch 88/100, Loss: 0.1333
# Epoch 89/100, Loss: 0.1294
# Epoch 90/100, Loss: 0.1255
# Epoch 91/100, Loss: 0.1180
# Epoch 92/100, Loss: 0.1173
# Epoch 93/100, Loss: 0.1184
# Epoch 94/100, Loss: 0.1157
# Epoch 95/100, Loss: 0.1124
# Epoch 96/100, Loss: 0.1069
# Epoch 97/100, Loss: 0.1086
# Epoch 98/100, Loss: 0.1049
# Epoch 99/100, Loss: 0.1375
# Epoch 100/100, Loss: 0.2683
# Epoch 1/100, Loss: 0.9705
# Epoch 2/100, Loss: 0.9324
# Epoch 3/100, Loss: 0.8588
# Epoch 4/100, Loss: 0.7620
# Epoch 5/100, Loss: 0.7699
# Epoch 6/100, Loss: 0.6842
# Epoch 7/100, Loss: 0.6666
# Epoch 8/100, Loss: 0.6318
# Epoch 9/100, Loss: 0.6424
# Epoch 10/100, Loss: 0.5539
# Epoch 11/100, Loss: 0.5459
# Epoch 12/100, Loss: 0.4754
# Epoch 13/100, Loss: 0.4338
# Epoch 14/100, Loss: 0.5369
# Epoch 15/100, Loss: 0.4107
# Epoch 16/100, Loss: 0.5517
# Epoch 17/100, Loss: 0.3908
# Epoch 18/100, Loss: 0.4394
# Epoch 19/100, Loss: 0.3470
# Epoch 20/100, Loss: 0.4298
# Epoch 21/100, Loss: 0.3348
# Epoch 22/100, Loss: 0.4041
# Epoch 23/100, Loss: 0.3515
# Epoch 24/100, Loss: 0.2982
# Epoch 25/100, Loss: 0.3015
# Epoch 26/100, Loss: 0.2863
# Epoch 27/100, Loss: 0.2926
# Epoch 28/100, Loss: 0.2654
# Epoch 29/100, Loss: 0.2741
# Epoch 30/100, Loss: 0.2581
# Epoch 31/100, Loss: 0.2870
# Epoch 32/100, Loss: 0.2606
# Epoch 33/100, Loss: 0.2562
# Epoch 34/100, Loss: 0.2804
# Epoch 35/100, Loss: 0.3017
# Epoch 36/100, Loss: 0.2214
# Epoch 37/100, Loss: 0.2010
# Epoch 38/100, Loss: 0.2109
# Epoch 39/100, Loss: 0.2205
# Epoch 40/100, Loss: 0.2392
# Epoch 41/100, Loss: 0.2188
# Epoch 42/100, Loss: 0.2261
# Epoch 43/100, Loss: 0.2024
# Epoch 44/100, Loss: 0.2180
# Epoch 45/100, Loss: 0.1796
# Epoch 46/100, Loss: 0.1793
# Epoch 47/100, Loss: 0.2041
# Epoch 48/100, Loss: 0.2473
# Epoch 49/100, Loss: 0.2094
# Epoch 50/100, Loss: 0.1805
# Epoch 51/100, Loss: 0.1857
# Epoch 52/100, Loss: 0.2113
# Epoch 53/100, Loss: 0.2236
# Epoch 54/100, Loss: 0.1859
# Epoch 55/100, Loss: 0.2402
# Epoch 56/100, Loss: 0.2862
# Epoch 57/100, Loss: 0.2162
# Epoch 58/100, Loss: 0.2125
# Epoch 59/100, Loss: 0.1757
# Epoch 60/100, Loss: 0.1660
# Epoch 61/100, Loss: 0.1762
# Epoch 62/100, Loss: 0.1866
# Epoch 63/100, Loss: 0.1662
# Epoch 64/100, Loss: 0.1583
# Epoch 65/100, Loss: 0.1479
# Epoch 66/100, Loss: 0.1437
# Epoch 67/100, Loss: 0.1346
# Epoch 68/100, Loss: 0.1332
# Epoch 69/100, Loss: 0.1279
# Epoch 70/100, Loss: 0.1323
# Epoch 71/100, Loss: 0.1287
# Epoch 72/100, Loss: 0.1223
# Epoch 73/100, Loss: 0.1204
# Epoch 74/100, Loss: 0.1219
# Epoch 75/100, Loss: 0.1180
# Epoch 76/100, Loss: 0.1142
# Epoch 77/100, Loss: 0.1120
# Epoch 78/100, Loss: 0.1111
# Epoch 79/100, Loss: 0.1120
# Epoch 80/100, Loss: 0.1107
# Epoch 81/100, Loss: 0.1081
# Epoch 82/100, Loss: 0.1182
# Epoch 83/100, Loss: 0.1857
# Epoch 84/100, Loss: 0.1349
# Epoch 85/100, Loss: 0.1335
# Epoch 86/100, Loss: 0.2131
# Epoch 87/100, Loss: 0.1301
# Epoch 88/100, Loss: 0.1535
# Epoch 89/100, Loss: 0.1563
# Epoch 90/100, Loss: 0.1510
# Epoch 91/100, Loss: 0.1518
# Epoch 92/100, Loss: 0.1951
# Epoch 93/100, Loss: 0.1418
# Epoch 94/100, Loss: 0.1457
# Epoch 95/100, Loss: 0.1300
# Epoch 96/100, Loss: 0.1216
# Epoch 97/100, Loss: 0.1213
# Epoch 98/100, Loss: 0.1280
# Epoch 99/100, Loss: 0.1245
# Epoch 100/100, Loss: 0.1372
# Epoch 1/100, Loss: 0.9733
# Epoch 2/100, Loss: 0.9409
# Epoch 3/100, Loss: 0.7801
# Epoch 4/100, Loss: 0.8393
# Epoch 5/100, Loss: 0.6500
# Epoch 6/100, Loss: 0.7622
# Epoch 7/100, Loss: 0.6233
# Epoch 8/100, Loss: 0.6528
# Epoch 9/100, Loss: 0.6460
# Epoch 10/100, Loss: 0.5492
# Epoch 11/100, Loss: 0.6007
# Epoch 12/100, Loss: 0.4980
# Epoch 13/100, Loss: 0.5230
# Epoch 14/100, Loss: 0.3999
# Epoch 15/100, Loss: 0.4243
# Epoch 16/100, Loss: 0.4290
# Epoch 17/100, Loss: 0.4795
# Epoch 18/100, Loss: 0.3982
# Epoch 19/100, Loss: 0.3879
# Epoch 20/100, Loss: 0.4672
# Epoch 21/100, Loss: 0.3731
# Epoch 22/100, Loss: 0.4612
# Epoch 23/100, Loss: 0.3462
# Epoch 24/100, Loss: 0.3299
# Epoch 25/100, Loss: 0.3458
# Epoch 26/100, Loss: 0.3052
# Epoch 27/100, Loss: 0.2865
# Epoch 28/100, Loss: 0.2971
# Epoch 29/100, Loss: 0.3316
# Epoch 30/100, Loss: 0.3025
# Epoch 31/100, Loss: 0.3351
# Epoch 32/100, Loss: 0.2981
# Epoch 33/100, Loss: 0.2805
# Epoch 34/100, Loss: 0.2650
# Epoch 35/100, Loss: 0.2750
# Epoch 36/100, Loss: 0.2544
# Epoch 37/100, Loss: 0.2312
# Epoch 38/100, Loss: 0.2134
# Epoch 39/100, Loss: 0.2029
# Epoch 40/100, Loss: 0.2007
# Epoch 41/100, Loss: 0.2019
# Epoch 42/100, Loss: 0.2526
# Epoch 43/100, Loss: 0.2420
# Epoch 44/100, Loss: 0.2452
# Epoch 45/100, Loss: 0.2820
# Epoch 46/100, Loss: 0.2537
# Epoch 47/100, Loss: 0.2736
# Epoch 48/100, Loss: 0.2312
# Epoch 49/100, Loss: 0.2401
# Epoch 50/100, Loss: 0.2409
# Epoch 51/100, Loss: 0.2041
# Epoch 52/100, Loss: 0.1914
# Epoch 53/100, Loss: 0.1825
# Epoch 54/100, Loss: 0.1849
# Epoch 55/100, Loss: 0.1895
# Epoch 56/100, Loss: 0.1746
# Epoch 57/100, Loss: 0.1677
# Epoch 58/100, Loss: 0.1633
# Epoch 59/100, Loss: 0.1813
# Epoch 60/100, Loss: 0.2434
# Epoch 61/100, Loss: 0.1777
# Epoch 62/100, Loss: 0.1795
# Epoch 63/100, Loss: 0.2013
# Epoch 64/100, Loss: 0.1945
# Epoch 65/100, Loss: 0.1710
# Epoch 66/100, Loss: 0.1551
# Epoch 67/100, Loss: 0.1477
# Epoch 68/100, Loss: 0.1438
# Epoch 69/100, Loss: 0.1412
# Epoch 70/100, Loss: 0.1343
# Epoch 71/100, Loss: 0.1339
# Epoch 72/100, Loss: 0.1338
# Epoch 73/100, Loss: 0.1578
# Epoch 74/100, Loss: 0.2158
# Epoch 75/100, Loss: 0.1698
# Epoch 76/100, Loss: 0.2284
# Epoch 77/100, Loss: 0.2345
# Epoch 78/100, Loss: 0.2319
# Epoch 79/100, Loss: 0.2490
# Epoch 80/100, Loss: 0.2306
# Epoch 81/100, Loss: 0.2281
# Epoch 82/100, Loss: 0.2021
# Epoch 83/100, Loss: 0.2199
# Epoch 84/100, Loss: 0.2247
# Epoch 85/100, Loss: 0.1873
# Epoch 86/100, Loss: 0.2029
# Epoch 87/100, Loss: 0.1512
# Epoch 88/100, Loss: 0.1446
# Epoch 89/100, Loss: 0.1385
# Epoch 90/100, Loss: 0.1354
# Epoch 91/100, Loss: 0.1299
# Epoch 92/100, Loss: 0.1277
# Epoch 93/100, Loss: 0.1266
# Epoch 94/100, Loss: 0.1229
# Epoch 95/100, Loss: 0.1200
# Epoch 96/100, Loss: 0.1186
# Epoch 97/100, Loss: 0.1167
# Epoch 98/100, Loss: 0.1142
# Epoch 99/100, Loss: 0.1147
# Epoch 100/100, Loss: 0.1163
# Epoch 1/100, Loss: 0.9728
# Epoch 2/100, Loss: 0.9302
# Epoch 3/100, Loss: 0.8286
# Epoch 4/100, Loss: 0.7987
# Epoch 5/100, Loss: 0.7292
# Epoch 6/100, Loss: 0.7368
# Epoch 7/100, Loss: 0.6321
# Epoch 8/100, Loss: 0.6296
# Epoch 9/100, Loss: 0.5517
# Epoch 10/100, Loss: 0.6387
# Epoch 11/100, Loss: 0.4655
# Epoch 12/100, Loss: 0.5660
# Epoch 13/100, Loss: 0.4593
# Epoch 14/100, Loss: 0.5175
# Epoch 15/100, Loss: 0.4265
# Epoch 16/100, Loss: 0.4751
# Epoch 17/100, Loss: 0.4151
# Epoch 18/100, Loss: 0.4018
# Epoch 19/100, Loss: 0.4007
# Epoch 20/100, Loss: 0.3473
# Epoch 21/100, Loss: 0.3461
# Epoch 22/100, Loss: 0.3590
# Epoch 23/100, Loss: 0.3281
# Epoch 24/100, Loss: 0.3155
# Epoch 25/100, Loss: 0.3775
# Epoch 26/100, Loss: 0.3509
# Epoch 27/100, Loss: 0.3493
# Epoch 28/100, Loss: 0.3213
# Epoch 29/100, Loss: 0.3122
# Epoch 30/100, Loss: 0.2740
# Epoch 31/100, Loss: 0.2563
# Epoch 32/100, Loss: 0.2649
# Epoch 33/100, Loss: 0.2740
# Epoch 34/100, Loss: 0.2635
# Epoch 35/100, Loss: 0.2968
# Epoch 36/100, Loss: 0.2491
# Epoch 37/100, Loss: 0.2417
# Epoch 38/100, Loss: 0.2430
# Epoch 39/100, Loss: 0.2510
# Epoch 40/100, Loss: 0.2775
# Epoch 41/100, Loss: 0.2512
# Epoch 42/100, Loss: 0.2331
# Epoch 43/100, Loss: 0.2411
# Epoch 44/100, Loss: 0.2444
# Epoch 45/100, Loss: 0.2128
# Epoch 46/100, Loss: 0.2073
# Epoch 47/100, Loss: 0.2101
# Epoch 48/100, Loss: 0.2386
# Epoch 49/100, Loss: 0.2300
# Epoch 50/100, Loss: 0.2436
# Epoch 51/100, Loss: 0.2458
# Epoch 52/100, Loss: 0.2164
# Epoch 53/100, Loss: 0.2195
# Epoch 54/100, Loss: 0.2096
# Epoch 55/100, Loss: 0.2096
# Epoch 56/100, Loss: 0.2074
# Epoch 57/100, Loss: 0.1977
# Epoch 58/100, Loss: 0.1810
# Epoch 59/100, Loss: 0.1965
# Epoch 60/100, Loss: 0.2271
# Epoch 61/100, Loss: 0.1797
# Epoch 62/100, Loss: 0.1738
# Epoch 63/100, Loss: 0.1673
# Epoch 64/100, Loss: 0.1631
# Epoch 65/100, Loss: 0.1596
# Epoch 66/100, Loss: 0.1528
# Epoch 67/100, Loss: 0.1505
# Epoch 68/100, Loss: 0.1639
# Epoch 69/100, Loss: 0.2269
# Epoch 70/100, Loss: 0.1664
# Epoch 71/100, Loss: 0.2037
# Epoch 72/100, Loss: 0.2001
# Epoch 73/100, Loss: 0.1819
# Epoch 74/100, Loss: 0.2163
# Epoch 75/100, Loss: 0.1698
# Epoch 76/100, Loss: 0.1687
# Epoch 77/100, Loss: 0.1771
# Epoch 78/100, Loss: 0.1834
# Epoch 79/100, Loss: 0.2727
# Epoch 80/100, Loss: 0.1782
# Epoch 81/100, Loss: 0.2264
# Epoch 82/100, Loss: 0.2355
# Epoch 83/100, Loss: 0.1985
# Epoch 84/100, Loss: 0.2543
# Epoch 85/100, Loss: 0.2148
# Epoch 86/100, Loss: 0.1668
# Epoch 87/100, Loss: 0.1536
# Epoch 88/100, Loss: 0.1494
# Epoch 89/100, Loss: 0.1426
# Epoch 90/100, Loss: 0.1433
# Epoch 91/100, Loss: 0.1347
# Epoch 92/100, Loss: 0.1346
# Epoch 93/100, Loss: 0.1316
# Epoch 94/100, Loss: 0.1333
# Epoch 95/100, Loss: 0.1286
# Epoch 96/100, Loss: 0.1284
# Epoch 97/100, Loss: 0.1273
# Epoch 98/100, Loss: 0.1250
# Epoch 99/100, Loss: 0.1249
# Epoch 100/100, Loss: 0.1235
# Epoch 1/100, Loss: 0.9724
# Epoch 2/100, Loss: 0.9363
# Epoch 3/100, Loss: 0.8110
# Epoch 4/100, Loss: 0.8080
# Epoch 5/100, Loss: 0.7243
# Epoch 6/100, Loss: 0.6759
# Epoch 7/100, Loss: 0.6918
# Epoch 8/100, Loss: 0.5550
# Epoch 9/100, Loss: 0.6533
# Epoch 10/100, Loss: 0.4982
# Epoch 11/100, Loss: 0.4419
# Epoch 12/100, Loss: 0.5317
# Epoch 13/100, Loss: 0.4308
# Epoch 14/100, Loss: 0.4612
# Epoch 15/100, Loss: 0.4171
# Epoch 16/100, Loss: 0.4617
# Epoch 17/100, Loss: 0.3764
# Epoch 18/100, Loss: 0.3863
# Epoch 19/100, Loss: 0.3675
# Epoch 20/100, Loss: 0.3302
# Epoch 21/100, Loss: 0.2963
# Epoch 22/100, Loss: 0.3034
# Epoch 23/100, Loss: 0.3435
# Epoch 24/100, Loss: 0.3375
# Epoch 25/100, Loss: 0.2847
# Epoch 26/100, Loss: 0.2735
# Epoch 27/100, Loss: 0.3044
# Epoch 28/100, Loss: 0.3237
# Epoch 29/100, Loss: 0.2670
# Epoch 30/100, Loss: 0.2483
# Epoch 31/100, Loss: 0.2439
# Epoch 32/100, Loss: 0.2317
# Epoch 33/100, Loss: 0.2430
# Epoch 34/100, Loss: 0.2349
# Epoch 35/100, Loss: 0.2319
# Epoch 36/100, Loss: 0.2110
# Epoch 37/100, Loss: 0.2263
# Epoch 38/100, Loss: 0.2055
# Epoch 39/100, Loss: 0.1971
# Epoch 40/100, Loss: 0.2041
# Epoch 41/100, Loss: 0.2155
# Epoch 42/100, Loss: 0.2327
# Epoch 43/100, Loss: 0.3547
# Epoch 44/100, Loss: 0.2251
# Epoch 45/100, Loss: 0.1975
# Epoch 46/100, Loss: 0.1938
# Epoch 47/100, Loss: 0.1856
# Epoch 48/100, Loss: 0.2350
# Epoch 49/100, Loss: 0.2527
# Epoch 50/100, Loss: 0.1836
# Epoch 51/100, Loss: 0.1903
# Epoch 52/100, Loss: 0.1976
# Epoch 53/100, Loss: 0.1692
# Epoch 54/100, Loss: 0.1641
# Epoch 55/100, Loss: 0.1725
# Epoch 56/100, Loss: 0.1752
# Epoch 57/100, Loss: 0.1639
# Epoch 58/100, Loss: 0.1650
# Epoch 59/100, Loss: 0.2060
# Epoch 60/100, Loss: 0.1733
# Epoch 61/100, Loss: 0.1624
# Epoch 62/100, Loss: 0.1566
# Epoch 63/100, Loss: 0.1578
# Epoch 64/100, Loss: 0.1582
# Epoch 65/100, Loss: 0.1673
# Epoch 66/100, Loss: 0.1521
# Epoch 67/100, Loss: 0.1446
# Epoch 68/100, Loss: 0.1448
# Epoch 69/100, Loss: 0.1360
# Epoch 70/100, Loss: 0.1327
# Epoch 71/100, Loss: 0.1300
# Epoch 72/100, Loss: 0.1260
# Epoch 73/100, Loss: 0.1241
# Epoch 74/100, Loss: 0.1338
# Epoch 75/100, Loss: 0.2991
# Epoch 76/100, Loss: 0.1601
# Epoch 77/100, Loss: 0.2376
# Epoch 78/100, Loss: 0.2287
# Epoch 79/100, Loss: 0.2380
# Epoch 80/100, Loss: 0.3018
# Epoch 81/100, Loss: 0.1852
# Epoch 82/100, Loss: 0.2644
# Epoch 83/100, Loss: 0.1660
# Epoch 84/100, Loss: 0.1786
# Epoch 85/100, Loss: 0.1779
# Epoch 86/100, Loss: 0.1655
# Epoch 87/100, Loss: 0.1542
# Epoch 88/100, Loss: 0.1681
# Epoch 89/100, Loss: 0.1413
# Epoch 90/100, Loss: 0.1316
# Epoch 91/100, Loss: 0.1248
# Epoch 92/100, Loss: 0.1254
# Epoch 93/100, Loss: 0.1222
# Epoch 94/100, Loss: 0.1217
# Epoch 95/100, Loss: 0.1206
# Epoch 96/100, Loss: 0.1173
# Epoch 97/100, Loss: 0.1131
# Epoch 98/100, Loss: 0.1123
# Epoch 99/100, Loss: 0.1147
# Epoch 100/100, Loss: 0.1072
# Epoch 1/100, Loss: 0.9705
# Epoch 2/100, Loss: 0.9565
# Epoch 3/100, Loss: 0.8038
# Epoch 4/100, Loss: 0.8628
# Epoch 5/100, Loss: 0.6991
# Epoch 6/100, Loss: 0.7958
# Epoch 7/100, Loss: 0.6094
# Epoch 8/100, Loss: 0.7342
# Epoch 9/100, Loss: 0.5587
# Epoch 10/100, Loss: 0.6388
# Epoch 11/100, Loss: 0.5777
# Epoch 12/100, Loss: 0.5143
# Epoch 13/100, Loss: 0.5197
# Epoch 14/100, Loss: 0.4597
# Epoch 15/100, Loss: 0.4584
# Epoch 16/100, Loss: 0.4651
# Epoch 17/100, Loss: 0.4331
# Epoch 18/100, Loss: 0.4435
# Epoch 19/100, Loss: 0.4348
# Epoch 20/100, Loss: 0.3309
# Epoch 21/100, Loss: 0.3222
# Epoch 22/100, Loss: 0.4015
# Epoch 23/100, Loss: 0.3928
# Epoch 24/100, Loss: 0.3516
# Epoch 25/100, Loss: 0.3121
# Epoch 26/100, Loss: 0.3547
# Epoch 27/100, Loss: 0.3391
# Epoch 28/100, Loss: 0.3121
# Epoch 29/100, Loss: 0.3444
# Epoch 30/100, Loss: 0.2754
# Epoch 31/100, Loss: 0.2729
# Epoch 32/100, Loss: 0.2794
# Epoch 33/100, Loss: 0.2860
# Epoch 34/100, Loss: 0.2482
# Epoch 35/100, Loss: 0.2328
# Epoch 36/100, Loss: 0.2213
# Epoch 37/100, Loss: 0.2413
# Epoch 38/100, Loss: 0.2366
# Epoch 39/100, Loss: 0.2345
# Epoch 40/100, Loss: 0.2196
# Epoch 41/100, Loss: 0.2166
# Epoch 42/100, Loss: 0.2075
# Epoch 43/100, Loss: 0.1995
# Epoch 44/100, Loss: 0.1883
# Epoch 45/100, Loss: 0.1803
# Epoch 46/100, Loss: 0.1764
# Epoch 47/100, Loss: 0.1898
# Epoch 48/100, Loss: 0.2152
# Epoch 49/100, Loss: 0.1818
# Epoch 50/100, Loss: 0.2606
# Epoch 51/100, Loss: 0.1947
# Epoch 52/100, Loss: 0.3194
# Epoch 53/100, Loss: 0.2553
# Epoch 54/100, Loss: 0.2518
# Epoch 55/100, Loss: 0.2722
# Epoch 56/100, Loss: 0.2129
# Epoch 57/100, Loss: 0.2013
# Epoch 58/100, Loss: 0.2034
# Epoch 59/100, Loss: 0.1920
# Epoch 60/100, Loss: 0.1747
# Epoch 61/100, Loss: 0.1614
# Epoch 62/100, Loss: 0.1581
# Epoch 63/100, Loss: 0.1415
# Epoch 64/100, Loss: 0.1463
# Epoch 65/100, Loss: 0.1377
# Epoch 66/100, Loss: 0.1373
# Epoch 67/100, Loss: 0.1347
# Epoch 68/100, Loss: 0.1311
# Epoch 69/100, Loss: 0.1289
# Epoch 70/100, Loss: 0.1241
# Epoch 71/100, Loss: 0.1253
# Epoch 72/100, Loss: 0.1222
# Epoch 73/100, Loss: 0.1197
# Epoch 74/100, Loss: 0.1236
# Epoch 75/100, Loss: 0.1781
# Epoch 76/100, Loss: 0.2484
# Epoch 77/100, Loss: 0.1611
# Epoch 78/100, Loss: 0.1903
# Epoch 79/100, Loss: 0.1700
# Epoch 80/100, Loss: 0.1666
# Epoch 81/100, Loss: 0.1892
# Epoch 82/100, Loss: 0.1631
# Epoch 83/100, Loss: 0.1646
# Epoch 84/100, Loss: 0.1626
# Epoch 85/100, Loss: 0.1525
# Epoch 86/100, Loss: 0.1343
# Epoch 87/100, Loss: 0.1244
# Epoch 88/100, Loss: 0.1212
# Epoch 89/100, Loss: 0.1177
# Epoch 90/100, Loss: 0.1146
# Epoch 91/100, Loss: 0.1100
# Epoch 92/100, Loss: 0.1100
# Epoch 93/100, Loss: 0.1090
# Epoch 94/100, Loss: 0.1065
# Epoch 95/100, Loss: 0.1046
# Epoch 96/100, Loss: 0.1024
# Epoch 97/100, Loss: 0.1031
# Epoch 98/100, Loss: 0.1019
# Epoch 99/100, Loss: 0.1011
# Epoch 100/100, Loss: 0.1323
# Epoch 1/100, Loss: 0.9773
# Epoch 2/100, Loss: 0.9314
# Epoch 3/100, Loss: 0.8067
# Epoch 4/100, Loss: 0.8378
# Epoch 5/100, Loss: 0.6705
# Epoch 6/100, Loss: 0.8011
# Epoch 7/100, Loss: 0.6468
# Epoch 8/100, Loss: 0.7094
# Epoch 9/100, Loss: 0.5912
# Epoch 10/100, Loss: 0.6879
# Epoch 11/100, Loss: 0.5119
# Epoch 12/100, Loss: 0.5994
# Epoch 13/100, Loss: 0.4492
# Epoch 14/100, Loss: 0.4836
# Epoch 15/100, Loss: 0.4221
# Epoch 16/100, Loss: 0.4831
# Epoch 17/100, Loss: 0.3904
# Epoch 18/100, Loss: 0.3858
# Epoch 19/100, Loss: 0.4030
# Epoch 20/100, Loss: 0.4330
# Epoch 21/100, Loss: 0.3946
# Epoch 22/100, Loss: 0.4147
# Epoch 23/100, Loss: 0.3329
# Epoch 24/100, Loss: 0.3646
# Epoch 25/100, Loss: 0.4163
# Epoch 26/100, Loss: 0.3091
# Epoch 27/100, Loss: 0.2898
# Epoch 28/100, Loss: 0.2983
# Epoch 29/100, Loss: 0.2953
# Epoch 30/100, Loss: 0.3251
# Epoch 31/100, Loss: 0.2899
# Epoch 32/100, Loss: 0.3114
# Epoch 33/100, Loss: 0.2770
# Epoch 34/100, Loss: 0.2683
# Epoch 35/100, Loss: 0.2693
# Epoch 36/100, Loss: 0.2744
# Epoch 37/100, Loss: 0.2539
# Epoch 38/100, Loss: 0.2390
# Epoch 39/100, Loss: 0.2408
# Epoch 40/100, Loss: 0.2407
# Epoch 41/100, Loss: 0.2496
# Epoch 42/100, Loss: 0.2523
# Epoch 43/100, Loss: 0.2353
# Epoch 44/100, Loss: 0.2571
# Epoch 45/100, Loss: 0.2327
# Epoch 46/100, Loss: 0.2222
# Epoch 47/100, Loss: 0.2295
# Epoch 48/100, Loss: 0.2074
# Epoch 49/100, Loss: 0.1897
# Epoch 50/100, Loss: 0.1815
# Epoch 51/100, Loss: 0.1729
# Epoch 52/100, Loss: 0.1634
# Epoch 53/100, Loss: 0.1673
# Epoch 54/100, Loss: 0.1653
# Epoch 55/100, Loss: 0.1608
# Epoch 56/100, Loss: 0.1571
# Epoch 57/100, Loss: 0.1581
# Epoch 58/100, Loss: 0.1593
# Epoch 59/100, Loss: 0.1884
# Epoch 60/100, Loss: 0.2882
# Epoch 61/100, Loss: 0.1880
# Epoch 62/100, Loss: 0.2313
# Epoch 63/100, Loss: 0.1800
# Epoch 64/100, Loss: 0.2117
# Epoch 65/100, Loss: 0.2529
# Epoch 66/100, Loss: 0.1694
# Epoch 67/100, Loss: 0.1551
# Epoch 68/100, Loss: 0.1491
# Epoch 69/100, Loss: 0.1438
# Epoch 70/100, Loss: 0.1389
# Epoch 71/100, Loss: 0.1365
# Epoch 72/100, Loss: 0.1366
# Epoch 73/100, Loss: 0.1319
# Epoch 74/100, Loss: 0.1325
# Epoch 75/100, Loss: 0.1277
# Epoch 76/100, Loss: 0.1288
# Epoch 77/100, Loss: 0.1427
# Epoch 78/100, Loss: 0.3010
# Epoch 79/100, Loss: 0.2026
# Epoch 80/100, Loss: 0.3689
# Epoch 81/100, Loss: 0.1967
# Epoch 82/100, Loss: 0.2503
# Epoch 83/100, Loss: 0.2287
# Epoch 84/100, Loss: 0.2281
# Epoch 85/100, Loss: 0.2504
# Epoch 86/100, Loss: 0.1731
# Epoch 87/100, Loss: 0.2251
# Epoch 88/100, Loss: 0.1879
# Epoch 89/100, Loss: 0.2015
# Epoch 90/100, Loss: 0.1911
# Epoch 91/100, Loss: 0.1992
# Epoch 92/100, Loss: 0.1649
# Epoch 93/100, Loss: 0.1515
# Epoch 94/100, Loss: 0.1463
# Epoch 95/100, Loss: 0.1736
# Epoch 96/100, Loss: 0.1545
# Epoch 97/100, Loss: 0.1359
# Epoch 98/100, Loss: 0.1316
# Epoch 99/100, Loss: 0.1233
# Epoch 100/100, Loss: 0.1231
# Epoch 1/100, Loss: 0.9719
# Epoch 2/100, Loss: 0.9532
# Epoch 3/100, Loss: 0.8173
# Epoch 4/100, Loss: 0.7119
# Epoch 5/100, Loss: 0.8251
# Epoch 6/100, Loss: 0.6497
# Epoch 7/100, Loss: 0.6284
# Epoch 8/100, Loss: 0.6625
# Epoch 9/100, Loss: 0.5083
# Epoch 10/100, Loss: 0.5785
# Epoch 11/100, Loss: 0.5207
# Epoch 12/100, Loss: 0.5415
# Epoch 13/100, Loss: 0.5001
# Epoch 14/100, Loss: 0.4351
# Epoch 15/100, Loss: 0.4320
# Epoch 16/100, Loss: 0.4192
# Epoch 17/100, Loss: 0.3856
# Epoch 18/100, Loss: 0.3973
# Epoch 19/100, Loss: 0.3538
# Epoch 20/100, Loss: 0.3434
# Epoch 21/100, Loss: 0.3063
# Epoch 22/100, Loss: 0.3059
# Epoch 23/100, Loss: 0.3088
# Epoch 24/100, Loss: 0.3593
# Epoch 25/100, Loss: 0.3462
# Epoch 26/100, Loss: 0.3213
# Epoch 27/100, Loss: 0.3124
# Epoch 28/100, Loss: 0.2642
# Epoch 29/100, Loss: 0.2713
# Epoch 30/100, Loss: 0.2725
# Epoch 31/100, Loss: 0.2980
# Epoch 32/100, Loss: 0.3016
# Epoch 33/100, Loss: 0.3037
# Epoch 34/100, Loss: 0.2864
# Epoch 35/100, Loss: 0.2774
# Epoch 36/100, Loss: 0.2717
# Epoch 37/100, Loss: 0.2476
# Epoch 38/100, Loss: 0.2269
# Epoch 39/100, Loss: 0.2263
# Epoch 40/100, Loss: 0.2160
# Epoch 41/100, Loss: 0.2340
# Epoch 42/100, Loss: 0.2125
# Epoch 43/100, Loss: 0.2125
# Epoch 44/100, Loss: 0.2053
# Epoch 45/100, Loss: 0.2038
# Epoch 46/100, Loss: 0.2110
# Epoch 47/100, Loss: 0.1905
# Epoch 48/100, Loss: 0.1900
# Epoch 49/100, Loss: 0.2597
# Epoch 50/100, Loss: 0.2559
# Epoch 51/100, Loss: 0.2049
# Epoch 52/100, Loss: 0.2014
# Epoch 53/100, Loss: 0.1964
# Epoch 54/100, Loss: 0.1927
# Epoch 55/100, Loss: 0.1893
# Epoch 56/100, Loss: 0.1987
# Epoch 57/100, Loss: 0.2096
# Epoch 58/100, Loss: 0.1996
# Epoch 59/100, Loss: 0.2127
# Epoch 60/100, Loss: 0.2466
# Epoch 61/100, Loss: 0.1953
# Epoch 62/100, Loss: 0.2080
# Epoch 63/100, Loss: 0.2082
# Epoch 64/100, Loss: 0.2037
# Epoch 65/100, Loss: 0.1937
# Epoch 66/100, Loss: 0.1744
# Epoch 67/100, Loss: 0.1634
# Epoch 68/100, Loss: 0.1611
# Epoch 69/100, Loss: 0.1518
# Epoch 70/100, Loss: 0.1509
# Epoch 71/100, Loss: 0.1476
# Epoch 72/100, Loss: 0.1463
# Epoch 73/100, Loss: 0.1432
# Epoch 74/100, Loss: 0.1463
# Epoch 75/100, Loss: 0.1669
# Epoch 76/100, Loss: 0.1439
# Epoch 77/100, Loss: 0.1432
# Epoch 78/100, Loss: 0.1457
# Epoch 79/100, Loss: 0.1359
# Epoch 80/100, Loss: 0.1340
# Epoch 81/100, Loss: 0.1283
# Epoch 82/100, Loss: 0.1397
# Epoch 83/100, Loss: 0.1770
# Epoch 84/100, Loss: 0.1339
# Epoch 85/100, Loss: 0.1337
# Epoch 86/100, Loss: 0.1388
# Epoch 87/100, Loss: 0.1725
# Epoch 88/100, Loss: 0.1711
# Epoch 89/100, Loss: 0.1839
# Epoch 90/100, Loss: 0.1930
# Epoch 91/100, Loss: 0.1820
# Epoch 92/100, Loss: 0.1626
# Epoch 93/100, Loss: 0.1806
# Epoch 94/100, Loss: 0.1801
# Epoch 95/100, Loss: 0.1725
# Epoch 96/100, Loss: 0.1457
# Epoch 97/100, Loss: 0.1343
# Epoch 98/100, Loss: 0.1299
# Epoch 99/100, Loss: 0.1283
# Epoch 100/100, Loss: 0.1200
# Epoch 1/100, Loss: 0.9731
# Epoch 2/100, Loss: 0.9385
# Epoch 3/100, Loss: 0.7934
# Epoch 4/100, Loss: 0.7949
# Epoch 5/100, Loss: 0.6537
# Epoch 6/100, Loss: 0.7699
# Epoch 7/100, Loss: 0.6069
# Epoch 8/100, Loss: 0.6447
# Epoch 9/100, Loss: 0.5654
# Epoch 10/100, Loss: 0.5947
# Epoch 11/100, Loss: 0.5011
# Epoch 12/100, Loss: 0.4974
# Epoch 13/100, Loss: 0.4673
# Epoch 14/100, Loss: 0.4584
# Epoch 15/100, Loss: 0.4267
# Epoch 16/100, Loss: 0.4266
# Epoch 17/100, Loss: 0.4873
# Epoch 18/100, Loss: 0.3730
# Epoch 19/100, Loss: 0.4185
# Epoch 20/100, Loss: 0.3248
# Epoch 21/100, Loss: 0.3182
# Epoch 22/100, Loss: 0.3364
# Epoch 23/100, Loss: 0.3290
# Epoch 24/100, Loss: 0.2937
# Epoch 25/100, Loss: 0.2989
# Epoch 26/100, Loss: 0.2958
# Epoch 27/100, Loss: 0.2682
# Epoch 28/100, Loss: 0.2569
# Epoch 29/100, Loss: 0.2882
# Epoch 30/100, Loss: 0.3405
# Epoch 31/100, Loss: 0.2951
# Epoch 32/100, Loss: 0.3225
# Epoch 33/100, Loss: 0.2818
# Epoch 34/100, Loss: 0.2486
# Epoch 35/100, Loss: 0.2237
# Epoch 36/100, Loss: 0.2130
# Epoch 37/100, Loss: 0.2016
# Epoch 38/100, Loss: 0.1951
# Epoch 39/100, Loss: 0.1905
# Epoch 40/100, Loss: 0.1881
# Epoch 41/100, Loss: 0.1838
# Epoch 42/100, Loss: 0.1980
# Epoch 43/100, Loss: 0.2197
# Epoch 44/100, Loss: 0.2289
# Epoch 45/100, Loss: 0.3016
# Epoch 46/100, Loss: 0.2200
# Epoch 47/100, Loss: 0.2408
# Epoch 48/100, Loss: 0.2629
# Epoch 49/100, Loss: 0.3020
# Epoch 50/100, Loss: 0.2464
# Epoch 51/100, Loss: 0.2191
# Epoch 52/100, Loss: 0.1998
# Epoch 53/100, Loss: 0.1969
# Epoch 54/100, Loss: 0.2075
# Epoch 55/100, Loss: 0.1817
# Epoch 56/100, Loss: 0.1752
# Epoch 57/100, Loss: 0.1749
# Epoch 58/100, Loss: 0.1633
# Epoch 59/100, Loss: 0.1631
# Epoch 60/100, Loss: 0.1519
# Epoch 61/100, Loss: 0.1519
# Epoch 62/100, Loss: 0.1460
# Epoch 63/100, Loss: 0.1468
# Epoch 64/100, Loss: 0.1447
# Epoch 65/100, Loss: 0.1396
# Epoch 66/100, Loss: 0.1345
# Epoch 67/100, Loss: 0.1342
# Epoch 68/100, Loss: 0.1301
# Epoch 69/100, Loss: 0.1318
# Epoch 70/100, Loss: 0.1288
# Epoch 71/100, Loss: 0.1287
# Epoch 72/100, Loss: 0.1297
# Epoch 73/100, Loss: 0.1434
# Epoch 74/100, Loss: 0.2351
# Epoch 75/100, Loss: 0.1741
# Epoch 76/100, Loss: 0.2227
# Epoch 77/100, Loss: 0.2218
# Epoch 78/100, Loss: 0.1638
# Epoch 79/100, Loss: 0.1714
# Epoch 80/100, Loss: 0.2464
# Epoch 81/100, Loss: 0.1972
# Epoch 82/100, Loss: 0.2271
# Epoch 83/100, Loss: 0.2931
# Epoch 84/100, Loss: 0.1628
# Epoch 85/100, Loss: 0.1534
# Epoch 86/100, Loss: 0.1417
# Epoch 87/100, Loss: 0.1382
# Epoch 88/100, Loss: 0.1335
# Epoch 89/100, Loss: 0.1326
# Epoch 90/100, Loss: 0.1292
# Epoch 91/100, Loss: 0.1272
# Epoch 92/100, Loss: 0.1234
# Epoch 93/100, Loss: 0.1240
# Epoch 94/100, Loss: 0.1171
# Epoch 95/100, Loss: 0.1191
# Epoch 96/100, Loss: 0.1150
# Epoch 97/100, Loss: 0.1174
# Epoch 98/100, Loss: 0.1114
# Epoch 99/100, Loss: 0.1129
# Epoch 100/100, Loss: 0.1126
# Epoch 1/100, Loss: 0.9784
# Epoch 2/100, Loss: 0.9507
# Epoch 3/100, Loss: 0.8348
# Epoch 4/100, Loss: 0.7883
# Epoch 5/100, Loss: 0.7586
# Epoch 6/100, Loss: 0.7260
# Epoch 7/100, Loss: 0.6441
# Epoch 8/100, Loss: 0.6458
# Epoch 9/100, Loss: 0.6410
# Epoch 10/100, Loss: 0.5797
# Epoch 11/100, Loss: 0.5723
# Epoch 12/100, Loss: 0.4455
# Epoch 13/100, Loss: 0.4738
# Epoch 14/100, Loss: 0.4464
# Epoch 15/100, Loss: 0.4428
# Epoch 16/100, Loss: 0.4173
# Epoch 17/100, Loss: 0.3993
# Epoch 18/100, Loss: 0.3377
# Epoch 19/100, Loss: 0.3855
# Epoch 20/100, Loss: 0.3977
# Epoch 21/100, Loss: 0.3189
# Epoch 22/100, Loss: 0.2846
# Epoch 23/100, Loss: 0.3103
# Epoch 24/100, Loss: 0.3669
# Epoch 25/100, Loss: 0.3193
# Epoch 26/100, Loss: 0.3056
# Epoch 27/100, Loss: 0.2862
# Epoch 28/100, Loss: 0.2564
# Epoch 29/100, Loss: 0.2441
# Epoch 30/100, Loss: 0.2609
# Epoch 31/100, Loss: 0.2532
# Epoch 32/100, Loss: 0.2726
# Epoch 33/100, Loss: 0.2910
# Epoch 34/100, Loss: 0.2683
# Epoch 35/100, Loss: 0.2572
# Epoch 36/100, Loss: 0.2930
# Epoch 37/100, Loss: 0.2875
# Epoch 38/100, Loss: 0.2435
# Epoch 39/100, Loss: 0.2383
# Epoch 40/100, Loss: 0.2154
# Epoch 41/100, Loss: 0.2139
# Epoch 42/100, Loss: 0.2078
# Epoch 43/100, Loss: 0.2034
# Epoch 44/100, Loss: 0.1897
# Epoch 45/100, Loss: 0.1926
# Epoch 46/100, Loss: 0.2090
# Epoch 47/100, Loss: 0.1866
# Epoch 48/100, Loss: 0.1764
# Epoch 49/100, Loss: 0.1741
# Epoch 50/100, Loss: 0.1729
# Epoch 51/100, Loss: 0.1659
# Epoch 52/100, Loss: 0.1741
# Epoch 53/100, Loss: 0.2044
# Epoch 54/100, Loss: 0.2129
# Epoch 55/100, Loss: 0.1768
# Epoch 56/100, Loss: 0.1768
# Epoch 57/100, Loss: 0.1752
# Epoch 58/100, Loss: 0.1775
# Epoch 59/100, Loss: 0.1995
# Epoch 60/100, Loss: 0.2228
# Epoch 61/100, Loss: 0.1939
# Epoch 62/100, Loss: 0.1772
# Epoch 63/100, Loss: 0.1815
# Epoch 64/100, Loss: 0.1578
# Epoch 65/100, Loss: 0.1544
# Epoch 66/100, Loss: 0.1499
# Epoch 67/100, Loss: 0.1460
# Epoch 68/100, Loss: 0.1378
# Epoch 69/100, Loss: 0.1392
# Epoch 70/100, Loss: 0.1383
# Epoch 71/100, Loss: 0.1330
# Epoch 72/100, Loss: 0.1317
# Epoch 73/100, Loss: 0.1292
# Epoch 74/100, Loss: 0.1304
# Epoch 75/100, Loss: 0.1254
# Epoch 76/100, Loss: 0.1260
# Epoch 77/100, Loss: 0.1261
# Epoch 78/100, Loss: 0.1235
# Epoch 79/100, Loss: 0.1505
# Epoch 80/100, Loss: 0.2592
# Epoch 81/100, Loss: 0.1654
# Epoch 82/100, Loss: 0.2285
# Epoch 83/100, Loss: 0.3100
# Epoch 84/100, Loss: 0.2092
# Epoch 85/100, Loss: 0.2870
# Epoch 86/100, Loss: 0.2370
# Epoch 87/100, Loss: 0.2029
# Epoch 88/100, Loss: 0.2084
# Epoch 89/100, Loss: 0.1685
# Epoch 90/100, Loss: 0.1713
# Epoch 91/100, Loss: 0.1585
# Epoch 92/100, Loss: 0.1405
# Epoch 93/100, Loss: 0.1373
# Epoch 94/100, Loss: 0.1309
# Epoch 95/100, Loss: 0.1315
# Epoch 96/100, Loss: 0.1265
# Epoch 97/100, Loss: 0.1239
# Epoch 98/100, Loss: 0.1208
# Epoch 99/100, Loss: 0.1200
# Epoch 100/100, Loss: 0.1223
# Epoch 1/100, Loss: 0.9677
# Epoch 2/100, Loss: 0.9182
# Epoch 3/100, Loss: 0.8378
# Epoch 4/100, Loss: 0.8177
# Epoch 5/100, Loss: 0.7982
# Epoch 6/100, Loss: 0.7298
# Epoch 7/100, Loss: 0.6648
# Epoch 8/100, Loss: 0.7044
# Epoch 9/100, Loss: 0.5921
# Epoch 10/100, Loss: 0.6784
# Epoch 11/100, Loss: 0.4669
# Epoch 12/100, Loss: 0.5518
# Epoch 13/100, Loss: 0.5544
# Epoch 14/100, Loss: 0.4330
# Epoch 15/100, Loss: 0.5273
# Epoch 16/100, Loss: 0.4486
# Epoch 17/100, Loss: 0.4828
# Epoch 18/100, Loss: 0.4018
# Epoch 19/100, Loss: 0.3731
# Epoch 20/100, Loss: 0.4113
# Epoch 21/100, Loss: 0.4414
# Epoch 22/100, Loss: 0.3562
# Epoch 23/100, Loss: 0.3408
# Epoch 24/100, Loss: 0.3513
# Epoch 25/100, Loss: 0.3376
# Epoch 26/100, Loss: 0.3429
# Epoch 27/100, Loss: 0.3246
# Epoch 28/100, Loss: 0.3315
# Epoch 29/100, Loss: 0.2898
# Epoch 30/100, Loss: 0.2817
# Epoch 31/100, Loss: 0.2685
# Epoch 32/100, Loss: 0.2673
# Epoch 33/100, Loss: 0.2905
# Epoch 34/100, Loss: 0.3331
# Epoch 35/100, Loss: 0.2986
# Epoch 36/100, Loss: 0.2797
# Epoch 37/100, Loss: 0.2951
# Epoch 38/100, Loss: 0.2669
# Epoch 39/100, Loss: 0.2295
# Epoch 40/100, Loss: 0.2165
# Epoch 41/100, Loss: 0.2052
# Epoch 42/100, Loss: 0.1995
# Epoch 43/100, Loss: 0.1971
# Epoch 44/100, Loss: 0.2167
# Epoch 45/100, Loss: 0.2272
# Epoch 46/100, Loss: 0.1905
# Epoch 47/100, Loss: 0.1911
# Epoch 48/100, Loss: 0.2139
# Epoch 49/100, Loss: 0.1987
# Epoch 50/100, Loss: 0.2027
# Epoch 51/100, Loss: 0.2511
# Epoch 52/100, Loss: 0.2225
# Epoch 53/100, Loss: 0.2303
# Epoch 54/100, Loss: 0.2168
# Epoch 55/100, Loss: 0.2893
# Epoch 56/100, Loss: 0.1947
# Epoch 57/100, Loss: 0.2544
# Epoch 58/100, Loss: 0.2355
# Epoch 59/100, Loss: 0.1962
# Epoch 60/100, Loss: 0.1810
# Epoch 61/100, Loss: 0.1748
# Epoch 62/100, Loss: 0.1682
# Epoch 63/100, Loss: 0.1602
# Epoch 64/100, Loss: 0.1614
# Epoch 65/100, Loss: 0.1521
# Epoch 66/100, Loss: 0.1471
# Epoch 67/100, Loss: 0.1472
# Epoch 68/100, Loss: 0.1414
# Epoch 69/100, Loss: 0.1399
# Epoch 70/100, Loss: 0.1375
# Epoch 71/100, Loss: 0.1405
# Epoch 72/100, Loss: 0.1334
# Epoch 73/100, Loss: 0.1350
# Epoch 74/100, Loss: 0.1295
# Epoch 75/100, Loss: 0.1266
# Epoch 76/100, Loss: 0.1242
# Epoch 77/100, Loss: 0.1253
# Epoch 78/100, Loss: 0.1251
# Epoch 79/100, Loss: 0.1239
# Epoch 80/100, Loss: 0.1311
# Epoch 81/100, Loss: 0.2129
# Epoch 82/100, Loss: 0.2118
# Epoch 83/100, Loss: 0.1955
# Epoch 84/100, Loss: 0.3613
# Epoch 85/100, Loss: 0.2743
# Epoch 86/100, Loss: 0.2765
# Epoch 87/100, Loss: 0.1929
# Epoch 88/100, Loss: 0.2398
# Epoch 89/100, Loss: 0.2164
# Epoch 90/100, Loss: 0.2386
# Epoch 91/100, Loss: 0.1922
# Epoch 92/100, Loss: 0.2499
# Epoch 93/100, Loss: 0.1554
# Epoch 94/100, Loss: 0.1788
# Epoch 95/100, Loss: 0.2089
# Epoch 96/100, Loss: 0.1676
# Epoch 97/100, Loss: 0.1894
# Epoch 98/100, Loss: 0.1630
# Epoch 99/100, Loss: 0.1857
# Epoch 100/100, Loss: 0.1637
# Epoch 1/100, Loss: 0.9694
# Epoch 2/100, Loss: 0.9288
# Epoch 3/100, Loss: 0.8429
# Epoch 4/100, Loss: 0.8252
# Epoch 5/100, Loss: 0.7060
# Epoch 6/100, Loss: 0.8047
# Epoch 7/100, Loss: 0.6897
# Epoch 8/100, Loss: 0.6917
# Epoch 9/100, Loss: 0.6509
# Epoch 10/100, Loss: 0.6447
# Epoch 11/100, Loss: 0.5342
# Epoch 12/100, Loss: 0.5817
# Epoch 13/100, Loss: 0.5731
# Epoch 14/100, Loss: 0.5038
# Epoch 15/100, Loss: 0.5053
# Epoch 16/100, Loss: 0.4475
# Epoch 17/100, Loss: 0.4869
# Epoch 18/100, Loss: 0.3850
# Epoch 19/100, Loss: 0.5184
# Epoch 20/100, Loss: 0.3979
# Epoch 21/100, Loss: 0.4025
# Epoch 22/100, Loss: 0.4119
# Epoch 23/100, Loss: 0.3555
# Epoch 24/100, Loss: 0.3546
# Epoch 25/100, Loss: 0.3611
# Epoch 26/100, Loss: 0.3472
# Epoch 27/100, Loss: 0.3376
# Epoch 28/100, Loss: 0.3665
# Epoch 29/100, Loss: 0.3476
# Epoch 30/100, Loss: 0.3269
# Epoch 31/100, Loss: 0.3097
# Epoch 32/100, Loss: 0.2921
# Epoch 33/100, Loss: 0.2838
# Epoch 34/100, Loss: 0.2901
# Epoch 35/100, Loss: 0.2832
# Epoch 36/100, Loss: 0.2688
# Epoch 37/100, Loss: 0.2830
# Epoch 38/100, Loss: 0.2399
# Epoch 39/100, Loss: 0.2442
# Epoch 40/100, Loss: 0.2627
# Epoch 41/100, Loss: 0.2750
# Epoch 42/100, Loss: 0.2694
# Epoch 43/100, Loss: 0.2580
# Epoch 44/100, Loss: 0.2253
# Epoch 45/100, Loss: 0.2108
# Epoch 46/100, Loss: 0.2052
# Epoch 47/100, Loss: 0.1983
# Epoch 48/100, Loss: 0.2157
# Epoch 49/100, Loss: 0.2623
# Epoch 50/100, Loss: 0.2341
# Epoch 51/100, Loss: 0.2868
# Epoch 52/100, Loss: 0.2780
# Epoch 53/100, Loss: 0.2617
# Epoch 54/100, Loss: 0.2544
# Epoch 55/100, Loss: 0.1981
# Epoch 56/100, Loss: 0.1934
# Epoch 57/100, Loss: 0.1899
# Epoch 58/100, Loss: 0.1886
# Epoch 59/100, Loss: 0.1813
# Epoch 60/100, Loss: 0.1735
# Epoch 61/100, Loss: 0.1710
# Epoch 62/100, Loss: 0.1636
# Epoch 63/100, Loss: 0.1622
# Epoch 64/100, Loss: 0.1573
# Epoch 65/100, Loss: 0.1530
# Epoch 66/100, Loss: 0.1554
# Epoch 67/100, Loss: 0.1594
# Epoch 68/100, Loss: 0.2142
# Epoch 69/100, Loss: 0.1869
# Epoch 70/100, Loss: 0.2288
# Epoch 71/100, Loss: 0.3008
# Epoch 72/100, Loss: 0.3138
# Epoch 73/100, Loss: 0.2163
# Epoch 74/100, Loss: 0.2025
# Epoch 75/100, Loss: 0.2457
# Epoch 76/100, Loss: 0.2322
# Epoch 77/100, Loss: 0.2428
# Epoch 78/100, Loss: 0.2236
# Epoch 79/100, Loss: 0.2037
# Epoch 80/100, Loss: 0.1952
# Epoch 81/100, Loss: 0.1815
# Epoch 82/100, Loss: 0.1687
# Epoch 83/100, Loss: 0.1560
# ...
# Epoch 7/100, Loss: 0.6238
# Epoch 8/100, Loss: 0.5828
# Epoch 9/100, Loss: 0.6055
# Epoch 10/100, Loss: 0.5045
# Epoch 11/100, Loss: 0.5976
# Epoch 12/100, Loss: 0.4983
# Epoch 13/100, Loss: 0.5541
# Epoch 14/100, Loss: 0.4257
# Epoch 15/100, Loss: 0.4384
# Epoch 16/100, Loss: 0.3756
# Epoch 17/100, Loss: 0.3673
# Epoch 18/100, Loss: 0.3719
# Epoch 19/100, Loss: 0.3829
# Epoch 20/100, Loss: 0.3712
# Epoch 21/100, Loss: 0.3881
# Epoch 22/100, Loss: 0.3659
# Epoch 23/100, Loss: 0.3278
# Epoch 24/100, Loss: 0.2965
# Epoch 25/100, Loss: 0.2897
# Epoch 26/100, Loss: 0.2811
# Epoch 27/100, Loss: 0.2691
# Epoch 28/100, Loss: 0.2567
# Epoch 29/100, Loss: 0.2487
# Epoch 30/100, Loss: 0.2569
# Epoch 31/100, Loss: 0.2437
# Epoch 32/100, Loss: 0.2388
# Epoch 33/100, Loss: 0.2466
# Epoch 34/100, Loss: 0.2596
# Epoch 35/100, Loss: 0.3025
# Epoch 36/100, Loss: 0.2812
# Epoch 37/100, Loss: 0.3044
# Epoch 38/100, Loss: 0.2933
# Epoch 39/100, Loss: 0.2998
# Epoch 40/100, Loss: 0.2523
# Epoch 41/100, Loss: 0.2491
# Epoch 42/100, Loss: 0.2645
# Epoch 43/100, Loss: 0.2283
# Epoch 44/100, Loss: 0.2075
# Epoch 45/100, Loss: 0.1881
# Epoch 46/100, Loss: 0.1852
# Epoch 47/100, Loss: 0.1836
# Epoch 48/100, Loss: 0.1750
# Epoch 49/100, Loss: 0.1764
# Epoch 50/100, Loss: 0.1728
# Epoch 51/100, Loss: 0.1706
# Epoch 52/100, Loss: 0.1685
# Epoch 53/100, Loss: 0.1636
# Epoch 54/100, Loss: 0.1591
# Epoch 55/100, Loss: 0.1699
# Epoch 56/100, Loss: 0.2313
# Epoch 57/100, Loss: 0.2245
# Epoch 58/100, Loss: 0.2062
# Epoch 59/100, Loss: 0.2085
# Epoch 60/100, Loss: 0.1836
# Epoch 61/100, Loss: 0.1811
# Epoch 62/100, Loss: 0.1772
# Epoch 63/100, Loss: 0.1734
# Epoch 64/100, Loss: 0.1746
# Epoch 65/100, Loss: 0.1985
# Epoch 66/100, Loss: 0.2849
# Epoch 67/100, Loss: 0.2240
# Epoch 68/100, Loss: 0.2874
# Epoch 69/100, Loss: 0.1936
# Epoch 70/100, Loss: 0.1786
# Epoch 71/100, Loss: 0.1679
# Epoch 72/100, Loss: 0.1554
# Epoch 73/100, Loss: 0.1549
# Epoch 74/100, Loss: 0.1512
# Epoch 75/100, Loss: 0.1464
# Epoch 76/100, Loss: 0.1426
# Epoch 77/100, Loss: 0.1411
# Epoch 78/100, Loss: 0.1381
# Epoch 79/100, Loss: 0.1343
# Epoch 80/100, Loss: 0.1320
# Epoch 81/100, Loss: 0.1340
# Epoch 82/100, Loss: 0.1268
# Epoch 83/100, Loss: 0.1260
# Epoch 84/100, Loss: 0.1281
# Epoch 85/100, Loss: 0.1284
# Epoch 86/100, Loss: 0.1468
# Epoch 87/100, Loss: 0.1828
# Epoch 88/100, Loss: 0.1614
# Epoch 89/100, Loss: 0.1896
# Epoch 90/100, Loss: 0.1742
# Epoch 91/100, Loss: 0.1528
# Epoch 92/100, Loss: 0.1660
# Epoch 93/100, Loss: 0.1698
# Epoch 94/100, Loss: 0.1461
# Epoch 95/100, Loss: 0.1341
# Epoch 96/100, Loss: 0.1450
# Epoch 97/100, Loss: 0.2835
# Epoch 98/100, Loss: 0.1942
# Epoch 99/100, Loss: 0.2776
# Epoch 100/100, Loss: 0.1801
# Epoch 1/100, Loss: 0.9709
# Epoch 2/100, Loss: 0.9282
# Epoch 3/100, Loss: 0.8021
# Epoch 4/100, Loss: 0.8636
# Epoch 5/100, Loss: 0.7711
# Epoch 6/100, Loss: 0.7199
# Epoch 7/100, Loss: 0.6840
# Epoch 8/100, Loss: 0.7329
# Epoch 9/100, Loss: 0.5963
# Epoch 10/100, Loss: 0.5967
# Epoch 11/100, Loss: 0.5616
# Epoch 12/100, Loss: 0.5730
# Epoch 13/100, Loss: 0.5241
# Epoch 14/100, Loss: 0.5021
# Epoch 15/100, Loss: 0.5209
# Epoch 16/100, Loss: 0.4077
# Epoch 17/100, Loss: 0.4663
# Epoch 18/100, Loss: 0.4258
# Epoch 19/100, Loss: 0.4811
# Epoch 20/100, Loss: 0.4168
# Epoch 21/100, Loss: 0.4160
# Epoch 22/100, Loss: 0.3555
# Epoch 23/100, Loss: 0.3221
# Epoch 24/100, Loss: 0.3458
# Epoch 25/100, Loss: 0.3982
# Epoch 26/100, Loss: 0.3148
# Epoch 27/100, Loss: 0.3464
# Epoch 28/100, Loss: 0.3125
# Epoch 29/100, Loss: 0.3086
# Epoch 30/100, Loss: 0.2803
# Epoch 31/100, Loss: 0.2884
# Epoch 32/100, Loss: 0.3354
# Epoch 33/100, Loss: 0.3597
# Epoch 34/100, Loss: 0.2952
# Epoch 35/100, Loss: 0.2843
# Epoch 36/100, Loss: 0.2876
# Epoch 37/100, Loss: 0.2891
# Epoch 38/100, Loss: 0.2633
# Epoch 39/100, Loss: 0.2658
# Epoch 40/100, Loss: 0.2724
# Epoch 41/100, Loss: 0.2566
# Epoch 42/100, Loss: 0.2268
# Epoch 43/100, Loss: 0.2116
# Epoch 44/100, Loss: 0.2071
# Epoch 45/100, Loss: 0.2199
# Epoch 46/100, Loss: 0.2255
# Epoch 47/100, Loss: 0.2072
# Epoch 48/100, Loss: 0.2037
# Epoch 49/100, Loss: 0.2110
# Epoch 50/100, Loss: 0.1876
# Epoch 51/100, Loss: 0.1892
# Epoch 52/100, Loss: 0.1945
# Epoch 53/100, Loss: 0.1945
# Epoch 54/100, Loss: 0.1868
# Epoch 55/100, Loss: 0.2149
# Epoch 56/100, Loss: 0.2156
# Epoch 57/100, Loss: 0.2993
# Epoch 58/100, Loss: 0.2010
# Epoch 59/100, Loss: 0.2205
# Epoch 60/100, Loss: 0.2117
# Epoch 61/100, Loss: 0.1805
# Epoch 62/100, Loss: 0.1726
# Epoch 63/100, Loss: 0.1810
# Epoch 64/100, Loss: 0.2879
# Epoch 65/100, Loss: 0.1802
# Epoch 66/100, Loss: 0.2159
# Epoch 67/100, Loss: 0.2879
# Epoch 68/100, Loss: 0.1941
# Epoch 69/100, Loss: 0.2235
# Epoch 70/100, Loss: 0.1883
# Epoch 71/100, Loss: 0.1772
# Epoch 72/100, Loss: 0.1603
# Epoch 73/100, Loss: 0.1548
# Epoch 74/100, Loss: 0.1517
# Epoch 75/100, Loss: 0.1464
# Epoch 76/100, Loss: 0.1416
# Epoch 77/100, Loss: 0.1422
# Epoch 78/100, Loss: 0.1361
# Epoch 79/100, Loss: 0.1356
# Epoch 80/100, Loss: 0.1408
# Epoch 81/100, Loss: 0.1838
# Epoch 82/100, Loss: 0.1834
# Epoch 83/100, Loss: 0.1651
# Epoch 84/100, Loss: 0.2359
# Epoch 85/100, Loss: 0.1805
# Epoch 86/100, Loss: 0.2177
# Epoch 87/100, Loss: 0.2550
# Epoch 88/100, Loss: 0.1729
# Epoch 89/100, Loss: 0.1669
# Epoch 90/100, Loss: 0.1608
# Epoch 91/100, Loss: 0.1744
# Epoch 92/100, Loss: 0.1574
# Epoch 93/100, Loss: 0.1461
# Epoch 94/100, Loss: 0.1489
# Epoch 95/100, Loss: 0.1496
# Epoch 96/100, Loss: 0.1471
# Epoch 97/100, Loss: 0.1449
# Epoch 98/100, Loss: 0.1515
# Epoch 99/100, Loss: 0.1608
# Epoch 100/100, Loss: 0.1273
# Epoch 1/100, Loss: 0.9720
# Epoch 2/100, Loss: 0.9151
# Epoch 3/100, Loss: 0.7908
# Epoch 4/100, Loss: 0.7899
# Epoch 5/100, Loss: 0.7190
# Epoch 6/100, Loss: 0.6583
# Epoch 7/100, Loss: 0.6140
# Epoch 8/100, Loss: 0.5918
# Epoch 9/100, Loss: 0.5320
# Epoch 10/100, Loss: 0.5195
# Epoch 11/100, Loss: 0.5061
# Epoch 12/100, Loss: 0.4126
# Epoch 13/100, Loss: 0.3786
# Epoch 14/100, Loss: 0.4810
# Epoch 15/100, Loss: 0.3987
# Epoch 16/100, Loss: 0.3957
# Epoch 17/100, Loss: 0.3791
# Epoch 18/100, Loss: 0.3784
# Epoch 19/100, Loss: 0.3971
# Epoch 20/100, Loss: 0.3640
# Epoch 21/100, Loss: 0.3224
# Epoch 22/100, Loss: 0.3258
# Epoch 23/100, Loss: 0.3407
# Epoch 24/100, Loss: 0.3053
# Epoch 25/100, Loss: 0.2846
# Epoch 26/100, Loss: 0.2470
# Epoch 27/100, Loss: 0.2540
# Epoch 28/100, Loss: 0.2627
# Epoch 29/100, Loss: 0.2480
# Epoch 30/100, Loss: 0.2502
# Epoch 31/100, Loss: 0.2824
# Epoch 32/100, Loss: 0.2632
# Epoch 33/100, Loss: 0.2806
# Epoch 34/100, Loss: 0.2443
# Epoch 35/100, Loss: 0.2284
# Epoch 36/100, Loss: 0.2157
# Epoch 37/100, Loss: 0.2009
# Epoch 38/100, Loss: 0.1945
# Epoch 39/100, Loss: 0.1937
# Epoch 40/100, Loss: 0.1906
# Epoch 41/100, Loss: 0.1869
# Epoch 42/100, Loss: 0.1901
# Epoch 43/100, Loss: 0.2052
# Epoch 44/100, Loss: 0.2442
# Epoch 45/100, Loss: 0.2161
# Epoch 46/100, Loss: 0.2226
# Epoch 47/100, Loss: 0.2376
# Epoch 48/100, Loss: 0.2225
# Epoch 49/100, Loss: 0.2255
# Epoch 50/100, Loss: 0.2197
# Epoch 51/100, Loss: 0.1818
# Epoch 52/100, Loss: 0.1705
# Epoch 53/100, Loss: 0.1664
# Epoch 54/100, Loss: 0.1587
# Epoch 55/100, Loss: 0.1570
# Epoch 56/100, Loss: 0.1515
# Epoch 57/100, Loss: 0.1456
# Epoch 58/100, Loss: 0.1455
# Epoch 59/100, Loss: 0.1450
# Epoch 60/100, Loss: 0.1405
# Epoch 61/100, Loss: 0.1360
# Epoch 62/100, Loss: 0.1434
# Epoch 63/100, Loss: 0.1837
# Epoch 64/100, Loss: 0.2137
# Epoch 65/100, Loss: 0.1960
# Epoch 66/100, Loss: 0.2700
# Epoch 67/100, Loss: 0.2107
# Epoch 68/100, Loss: 0.2671
# Epoch 69/100, Loss: 0.2619
# Epoch 70/100, Loss: 0.2439
# Epoch 71/100, Loss: 0.1882
# Epoch 72/100, Loss: 0.1808
# Epoch 73/100, Loss: 0.1787
# Epoch 74/100, Loss: 0.1685
# Epoch 75/100, Loss: 0.1470
# Epoch 76/100, Loss: 0.1415
# Epoch 77/100, Loss: 0.1381
# Epoch 78/100, Loss: 0.1334
# Epoch 79/100, Loss: 0.1310
# Epoch 80/100, Loss: 0.1292
# Epoch 81/100, Loss: 0.1285
# Epoch 82/100, Loss: 0.1279
# Epoch 83/100, Loss: 0.1292
# Epoch 84/100, Loss: 0.1467
# Epoch 85/100, Loss: 0.1954
# Epoch 86/100, Loss: 0.1455
# Epoch 87/100, Loss: 0.1542
# Epoch 88/100, Loss: 0.1971
# Epoch 89/100, Loss: 0.1421
# Epoch 90/100, Loss: 0.1335
# Epoch 91/100, Loss: 0.1311
# Epoch 92/100, Loss: 0.1280
# Epoch 93/100, Loss: 0.1288
# Epoch 94/100, Loss: 0.1249
# Epoch 95/100, Loss: 0.1403
# Epoch 96/100, Loss: 0.1409
# Epoch 97/100, Loss: 0.1461
# Epoch 98/100, Loss: 0.1390
# Epoch 99/100, Loss: 0.1492
# Epoch 100/100, Loss: 0.1264
# Epoch 1/100, Loss: 0.9746
# Epoch 2/100, Loss: 0.9270
# Epoch 3/100, Loss: 0.8442
# Epoch 4/100, Loss: 0.7993
# Epoch 5/100, Loss: 0.7061
# Epoch 6/100, Loss: 0.7749
# Epoch 7/100, Loss: 0.6290
# Epoch 8/100, Loss: 0.6914
# Epoch 9/100, Loss: 0.5646
# Epoch 10/100, Loss: 0.6000
# Epoch 11/100, Loss: 0.5393
# Epoch 12/100, Loss: 0.5501
# Epoch 13/100, Loss: 0.4552
# Epoch 14/100, Loss: 0.3978
# Epoch 15/100, Loss: 0.5526
# Epoch 16/100, Loss: 0.3742
# Epoch 17/100, Loss: 0.4516
# Epoch 18/100, Loss: 0.4305
# Epoch 19/100, Loss: 0.3972
# Epoch 20/100, Loss: 0.3687
# Epoch 21/100, Loss: 0.4091
# Epoch 22/100, Loss: 0.3433
# Epoch 23/100, Loss: 0.3541
# Epoch 24/100, Loss: 0.3190
# Epoch 25/100, Loss: 0.3219
# Epoch 26/100, Loss: 0.2895
# Epoch 27/100, Loss: 0.3110
# Epoch 28/100, Loss: 0.3243
# Epoch 29/100, Loss: 0.3632
# Epoch 30/100, Loss: 0.2801
# Epoch 31/100, Loss: 0.2849
# Epoch 32/100, Loss: 0.2652
# Epoch 33/100, Loss: 0.2614
# Epoch 34/100, Loss: 0.2352
# Epoch 35/100, Loss: 0.2505
# Epoch 36/100, Loss: 0.2281
# Epoch 37/100, Loss: 0.2573
# Epoch 38/100, Loss: 0.2481
# Epoch 39/100, Loss: 0.2231
# Epoch 40/100, Loss: 0.2055
# Epoch 41/100, Loss: 0.2183
# Epoch 42/100, Loss: 0.2176
# Epoch 43/100, Loss: 0.2132
# Epoch 44/100, Loss: 0.2059
# Epoch 45/100, Loss: 0.2128
# Epoch 46/100, Loss: 0.2174
# Epoch 47/100, Loss: 0.2861
# Epoch 48/100, Loss: 0.2890
# Epoch 49/100, Loss: 0.2203
# Epoch 50/100, Loss: 0.2415
# Epoch 51/100, Loss: 0.2138
# Epoch 52/100, Loss: 0.2091
# Epoch 53/100, Loss: 0.2805
# Epoch 54/100, Loss: 0.2071
# Epoch 55/100, Loss: 0.1864
# Epoch 56/100, Loss: 0.1738
# Epoch 57/100, Loss: 0.1651
# Epoch 58/100, Loss: 0.1757
# Epoch 59/100, Loss: 0.1767
# Epoch 60/100, Loss: 0.1849
# Epoch 61/100, Loss: 0.1645
# Epoch 62/100, Loss: 0.1680
# Epoch 63/100, Loss: 0.1705
# Epoch 64/100, Loss: 0.1681
# Epoch 65/100, Loss: 0.1518
# Epoch 66/100, Loss: 0.1501
# Epoch 67/100, Loss: 0.1422
# Epoch 68/100, Loss: 0.1428
# Epoch 69/100, Loss: 0.1446
# Epoch 70/100, Loss: 0.1762
# Epoch 71/100, Loss: 0.1673
# Epoch 72/100, Loss: 0.1790
# Epoch 73/100, Loss: 0.1601
# Epoch 74/100, Loss: 0.1876
# Epoch 75/100, Loss: 0.2756
# Epoch 76/100, Loss: 0.2018
# Epoch 77/100, Loss: 0.1824
# Epoch 78/100, Loss: 0.2323
# Epoch 79/100, Loss: 0.2253
# Epoch 80/100, Loss: 0.2387
# Epoch 81/100, Loss: 0.2128
# Epoch 82/100, Loss: 0.1682
# Epoch 83/100, Loss: 0.1850
# Epoch 84/100, Loss: 0.1704
# Epoch 85/100, Loss: 0.1548
# Epoch 86/100, Loss: 0.1433
# Epoch 87/100, Loss: 0.1356
# Epoch 88/100, Loss: 0.1311
# Epoch 89/100, Loss: 0.1306
# Epoch 90/100, Loss: 0.1307
# Epoch 91/100, Loss: 0.1225
# Epoch 92/100, Loss: 0.1217
# Epoch 93/100, Loss: 0.1203
# Epoch 94/100, Loss: 0.1264
# Epoch 95/100, Loss: 0.1634
# Epoch 96/100, Loss: 0.1760
# Epoch 97/100, Loss: 0.1496
# Epoch 98/100, Loss: 0.1473
# Epoch 99/100, Loss: 0.1394
# Epoch 100/100, Loss: 0.1439
# Epoch 1/100, Loss: 0.9728
# Epoch 2/100, Loss: 0.9395
# Epoch 3/100, Loss: 0.8286
# Epoch 4/100, Loss: 0.8238
# Epoch 5/100, Loss: 0.7474
# Epoch 6/100, Loss: 0.7428
# Epoch 7/100, Loss: 0.6113
# Epoch 8/100, Loss: 0.7302
# Epoch 9/100, Loss: 0.6066
# Epoch 10/100, Loss: 0.6262
# Epoch 11/100, Loss: 0.5653
# Epoch 12/100, Loss: 0.5621
# Epoch 13/100, Loss: 0.4894
# Epoch 14/100, Loss: 0.5143
# Epoch 15/100, Loss: 0.5128
# Epoch 16/100, Loss: 0.4370
# Epoch 17/100, Loss: 0.4477
# Epoch 18/100, Loss: 0.3934
# Epoch 19/100, Loss: 0.4273
# Epoch 20/100, Loss: 0.4370
# Epoch 21/100, Loss: 0.3767
# Epoch 22/100, Loss: 0.4364
# Epoch 23/100, Loss: 0.3568
# Epoch 24/100, Loss: 0.3582
# Epoch 25/100, Loss: 0.4108
# Epoch 26/100, Loss: 0.3139
# Epoch 27/100, Loss: 0.3487
# Epoch 28/100, Loss: 0.3258
# Epoch 29/100, Loss: 0.3134
# Epoch 30/100, Loss: 0.2732
# Epoch 31/100, Loss: 0.3357
# Epoch 32/100, Loss: 0.3287
# Epoch 33/100, Loss: 0.2711
# Epoch 34/100, Loss: 0.2818
# Epoch 35/100, Loss: 0.2670
# Epoch 36/100, Loss: 0.2548
# Epoch 37/100, Loss: 0.2857
# Epoch 38/100, Loss: 0.3281
# Epoch 39/100, Loss: 0.2683
# Epoch 40/100, Loss: 0.2501
# Epoch 41/100, Loss: 0.2439
# Epoch 42/100, Loss: 0.3015
# Epoch 43/100, Loss: 0.3218
# Epoch 44/100, Loss: 0.2658
# Epoch 45/100, Loss: 0.2422
# Epoch 46/100, Loss: 0.2413
# Epoch 47/100, Loss: 0.2156
# Epoch 48/100, Loss: 0.2024
# Epoch 49/100, Loss: 0.1946
# Epoch 50/100, Loss: 0.1852
# Epoch 51/100, Loss: 0.1790
# Epoch 52/100, Loss: 0.1784
# Epoch 53/100, Loss: 0.1924
# Epoch 54/100, Loss: 0.2433
# Epoch 55/100, Loss: 0.1843
# Epoch 56/100, Loss: 0.2101
# Epoch 57/100, Loss: 0.2914
# Epoch 58/100, Loss: 0.2729
# Epoch 59/100, Loss: 0.2468
# Epoch 60/100, Loss: 0.2535
# Epoch 61/100, Loss: 0.2210
# Epoch 62/100, Loss: 0.1975
# Epoch 63/100, Loss: 0.2148
# Epoch 64/100, Loss: 0.1996
# Epoch 65/100, Loss: 0.2131
# Epoch 66/100, Loss: 0.2222
# Epoch 67/100, Loss: 0.2476
# Epoch 68/100, Loss: 0.1922
# Epoch 69/100, Loss: 0.1855
# Epoch 70/100, Loss: 0.1649
# Epoch 71/100, Loss: 0.1622
# Epoch 72/100, Loss: 0.1538
# Epoch 73/100, Loss: 0.1566
# Epoch 74/100, Loss: 0.1512
# Epoch 75/100, Loss: 0.1470
# Epoch 76/100, Loss: 0.1460
# Epoch 77/100, Loss: 0.1489
# Epoch 78/100, Loss: 0.2109
# Epoch 79/100, Loss: 0.1734
# Epoch 80/100, Loss: 0.2159
# Epoch 81/100, Loss: 0.1940
# Epoch 82/100, Loss: 0.1807
# Epoch 83/100, Loss: 0.1863
# Epoch 84/100, Loss: 0.1789
# Epoch 85/100, Loss: 0.1585
# Epoch 86/100, Loss: 0.1674
# Epoch 87/100, Loss: 0.2038
# Epoch 88/100, Loss: 0.2657
# Epoch 89/100, Loss: 0.1758
# Epoch 90/100, Loss: 0.2249
# Epoch 91/100, Loss: 0.1748
# Epoch 92/100, Loss: 0.1813
# Epoch 93/100, Loss: 0.2128
# Epoch 94/100, Loss: 0.1535
# Epoch 95/100, Loss: 0.1441
# Epoch 96/100, Loss: 0.1381
# Epoch 97/100, Loss: 0.1395
# Epoch 98/100, Loss: 0.1316
# Epoch 99/100, Loss: 0.1300
# Epoch 100/100, Loss: 0.1259
# Epoch 1/100, Loss: 0.9725
# Epoch 2/100, Loss: 0.9345
# Epoch 3/100, Loss: 0.8093
# Epoch 4/100, Loss: 0.8295
# Epoch 5/100, Loss: 0.6624
# Epoch 6/100, Loss: 0.7379
# Epoch 7/100, Loss: 0.5783
# Epoch 8/100, Loss: 0.7091
# Epoch 9/100, Loss: 0.5656
# Epoch 10/100, Loss: 0.5134
# Epoch 11/100, Loss: 0.5820
# Epoch 12/100, Loss: 0.4832
# Epoch 13/100, Loss: 0.5394
# Epoch 14/100, Loss: 0.4377
# Epoch 15/100, Loss: 0.4699
# Epoch 16/100, Loss: 0.3998
# Epoch 17/100, Loss: 0.4412
# Epoch 18/100, Loss: 0.3865
# Epoch 19/100, Loss: 0.3713
# Epoch 20/100, Loss: 0.3331
# Epoch 21/100, Loss: 0.3496
# Epoch 22/100, Loss: 0.3462
# Epoch 23/100, Loss: 0.3534
# Epoch 24/100, Loss: 0.3549
# Epoch 25/100, Loss: 0.3489
# Epoch 26/100, Loss: 0.3340
# Epoch 27/100, Loss: 0.3082
# Epoch 28/100, Loss: 0.3072
# Epoch 29/100, Loss: 0.2959
# Epoch 30/100, Loss: 0.3261
# Epoch 31/100, Loss: 0.2936
# Epoch 32/100, Loss: 0.2856
# Epoch 33/100, Loss: 0.2644
# Epoch 34/100, Loss: 0.2647
# Epoch 35/100, Loss: 0.2485
# Epoch 36/100, Loss: 0.2344
# Epoch 37/100, Loss: 0.2288
# Epoch 38/100, Loss: 0.2351
# Epoch 39/100, Loss: 0.2228
# Epoch 40/100, Loss: 0.2734
# Epoch 41/100, Loss: 0.2952
# Epoch 42/100, Loss: 0.2134
# Epoch 43/100, Loss: 0.2153
# Epoch 44/100, Loss: 0.2193
# Epoch 45/100, Loss: 0.2214
# Epoch 46/100, Loss: 0.2050
# Epoch 47/100, Loss: 0.2089
# Epoch 48/100, Loss: 0.2088
# Epoch 49/100, Loss: 0.2092
# Epoch 50/100, Loss: 0.2131
# Epoch 51/100, Loss: 0.1909
# Epoch 52/100, Loss: 0.1733
# Epoch 53/100, Loss: 0.1695
# Epoch 54/100, Loss: 0.1670
# Epoch 55/100, Loss: 0.1657
# Epoch 56/100, Loss: 0.2075
# Epoch 57/100, Loss: 0.2088
# Epoch 58/100, Loss: 0.2742
# Epoch 59/100, Loss: 0.2298
# Epoch 60/100, Loss: 0.2250
# Epoch 61/100, Loss: 0.2231
# Epoch 62/100, Loss: 0.2484
# Epoch 63/100, Loss: 0.2239
# Epoch 64/100, Loss: 0.1960
# Epoch 65/100, Loss: 0.2004
# Epoch 66/100, Loss: 0.2259
# Epoch 67/100, Loss: 0.1850
# Epoch 68/100, Loss: 0.1678
# Epoch 69/100, Loss: 0.1628
# Epoch 70/100, Loss: 0.1553
# Epoch 71/100, Loss: 0.1522
# Epoch 72/100, Loss: 0.1472
# Epoch 73/100, Loss: 0.1424
# Epoch 74/100, Loss: 0.1414
# Epoch 75/100, Loss: 0.1396
# Epoch 76/100, Loss: 0.1380
# Epoch 77/100, Loss: 0.1320
# Epoch 78/100, Loss: 0.1323
# Epoch 79/100, Loss: 0.1310
# Epoch 80/100, Loss: 0.1294
# Epoch 81/100, Loss: 0.1247
# Epoch 82/100, Loss: 0.1250
# Epoch 83/100, Loss: 0.1272
# Epoch 84/100, Loss: 0.1795
# Epoch 85/100, Loss: 0.2164
# Epoch 86/100, Loss: 0.2070
# Epoch 87/100, Loss: 0.2369
# Epoch 88/100, Loss: 0.1665
# Epoch 89/100, Loss: 0.1902
# Epoch 90/100, Loss: 0.2064
# Epoch 91/100, Loss: 0.2505
# Epoch 92/100, Loss: 0.1724
# Epoch 93/100, Loss: 0.2454
# Epoch 94/100, Loss: 0.1580
# Epoch 95/100, Loss: 0.1467
# Epoch 96/100, Loss: 0.1488
# Epoch 97/100, Loss: 0.1649
# Epoch 98/100, Loss: 0.1524
# Epoch 99/100, Loss: 0.1338
# Epoch 100/100, Loss: 0.1282

# %%
observables_test = X[10000:10000]
observables_train= X[:10000]

# %% [markdown]
# ---

# %%
unmixed_train_all_concat = np.load("results/neural_unmixed_train_all_concat.npy")
unmixed_test_all_concat = np.load("results/neural_unmixed_test_all_concat.npy")

# %%
unmixed_train_all_concat = np.concatenate([np.transpose(i,(1,0,2)) for i in unmixed_train_all])
unmixed_test_all_concat = np.concatenate([np.transpose(i,(1,0,2)) for i in unmixed_test_all])

# %%
plt.plot(unmixed_train_all_concat[4,:1000,3])

# %%
ccm_unmixed_train = CCM.PairwiseCCM().compute(unmixed_train_all_concat,unmixed_train_all_concat,1500,600,60,0,method="simplex",nbrs_num=10,).mean(axis=0)
ccm_unmixed_test = CCM.PairwiseCCM().compute(unmixed_test_all_concat,unmixed_test_all_concat,1500,600,60,0,method="simplex",nbrs_num=10,).mean(axis=0)

ccm_unmixed_train[ccm_unmixed_train<0]=0
ccm_unmixed_test[ccm_unmixed_test<0]=0

# %%
unmixed_xmap_X_train = [np.mean([CCM.PairwiseCCM().compute(unmixed_train_all_concat[[i]],X[:observables_train.shape[0],].T[:,:,None],1200,600,60,0,method="simplex",nbrs_num=10,).mean(axis=0) for exp in range(5)] ,axis=0) for i in range(unmixed_train_all_concat.shape[0])]
unmixed_xmap_X_train = np.array(unmixed_xmap_X_train).T[0]
unmixed_xmap_X_train[unmixed_xmap_X_train<0]=0

unmixed_xmap_X_test = [np.mean([CCM.PairwiseCCM().compute(unmixed_test_all_concat[[i]],X[observables_train.shape[0]:,].T[:,:,None],1200,600,60,0,method="simplex",nbrs_num=10,).mean(axis=0) for exp in range(5)] ,axis=0) for i in range(unmixed_test_all_concat.shape[0])]
unmixed_xmap_X_test = np.array(unmixed_xmap_X_test).T[0]
unmixed_xmap_X_test[unmixed_xmap_X_test<0]=0
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 unmixed_xmap_X_train = [np.mean([CCM.PairwiseCCM().compute(unmixed_train_all_concat[[i]],X[:observables_train.shape[0],].T[:,:,None],1200,600,60,0,method="simplex",nbrs_num=10,).mean(axis=0) for exp in range(5)] ,axis=0) for i in range(unmixed_train_all_concat.shape[0])]
#       2 unmixed_xmap_X_train = np.array(unmixed_xmap_X_train).T[0]
#       3 unmixed_xmap_X_train[unmixed_xmap_X_train<0]=0
#
# File ~/Documents/Python projects/FastCCM/src/FastCCM/CCM.py:81, in PairwiseCCM.compute(self, X, Y, subset_size, subsample_size, exclusion_rad, tp, method, **kwargs)
#      79 X_lib = self.__get_random_sample(X, min_len, lib_indices, num_ts_X, max_E_X)
#      80 X_sample = self.__get_random_sample(X, min_len, smpl_indices, num_ts_X, max_E_X)
# ---> 81 Y_lib_shifted = self.__get_random_sample(Y, min_len, lib_indices + tp, num_ts_Y, max_E_Y)
#      82 Y_sample_shifted = self.__get_random_sample(Y, min_len, smpl_indices + tp, num_ts_Y, max_E_Y)
#      84 if method == "simplex":
#
# File ~/Documents/Python projects/FastCCM/src/FastCCM/CCM.py:259, in PairwiseCCM.__get_random_sample(self, X, min_len, indices, dim, max_E)
#     256 X_buf = torch.zeros((dim, indices.shape[0], max_E),device=self.device)
#     258 for i in range(dim):
# --> 259     X_buf[i,:,:X[i].shape[-1]] = torch.tensor(X[i][-min_len:],device=self.device)[indices]
#     261 return X_buf
#
# KeyboardInterrupt:

# %%
plt.matshow(ccm_unmixed_train,vmin=0,vmax=1)

# Generate the clustermap and get the linkage matrix for the columns
clustermap = sns.clustermap(ccm_unmixed_train + ccm_unmixed_train.T,method="average", col_cluster=True)
col_linkage = clustermap.dendrogram_col.linkage

n_clusters = 6
col_clusters = sch.cut_tree(col_linkage, n_clusters=n_clusters).flatten()

# Initialize a dictionary to store the barycenter variable for each cluster
barycenter_vars = []

# Iterate through each cluster
for cluster in range(n_clusters):
    # Get the indices of columns in this cluster
    cluster_indices = np.where(col_clusters == cluster)[0]
    
    # Extract the submatrix for this cluster
    cluster_matrix = ccm_unmixed_train[np.ix_(cluster_indices, cluster_indices)]
    
    # Calculate the average correlation for each variable in the cluster
    avg_correlations = cluster_matrix.mean(axis=1)
    
    # Find the index of the variable with the highest average correlation
    closest_variable_idx = cluster_indices[np.argmax(avg_correlations)]
    
    # Store the result
    barycenter_vars += [closest_variable_idx]
barycenter_vars = np.array(barycenter_vars)

ccm_unmixed_train_reduced = np.array([[ccm_unmixed_train[col_clusters==j][:,col_clusters==i].mean() for i in range(col_clusters.max()+1)] for j in range(col_clusters.max()+1)])

ccm_unmixed_train_reduced = CCM.PairwiseCCM().compute(unmixed_train_all_concat[barycenter_vars],unmixed_train_all_concat[barycenter_vars],1500,600,60,0,method="simplex").mean(axis=0)
ccm_unmixed_train_reduced[ccm_unmixed_train_reduced<0]=0

unmixed_xmap_X_train_reduced = [np.mean([CCM.PairwiseCCM().compute(unmixed_train_all_concat[[i]],observables_train[:,:X.shape[1]].T[:,:,None],1200,600,60,0,method="simplex",).mean(axis=0) for exp in range(5)] ,axis=0) for i in barycenter_vars]
unmixed_xmap_X_train_reduced = np.array(unmixed_xmap_X_train_reduced).T[0]
unmixed_xmap_X_train_reduced[unmixed_xmap_X_train_reduced<0]=0

unmixed_xmap_X_test_reduced = [np.mean([CCM.PairwiseCCM().compute(unmixed_test_all_concat[[i]],observables_test[:,:X.shape[1]].T[:,:,None],1200,600,60,0,method="simplex",).mean(axis=0) for exp in range(5)] ,axis=0) for i in barycenter_vars]
unmixed_xmap_X_test_reduced = np.array(unmixed_xmap_X_test_reduced).T[0]
unmixed_xmap_X_test_reduced[unmixed_xmap_X_test_reduced<0]=0

X_xmap_unmixed_train_reduced = [np.mean([CCM.PairwiseCCM().compute(np.transpose(utils.get_td_embedding_np(observables_train[:,:62],3,5),(2,0,1))[[i]],unmixed_train_all_concat[barycenter_vars][:,:,[0]],1200,600,60,0,method="simplex",).mean(axis=0) for exp in range(5)] ,axis=0) for i in range(62)]
X_xmap_unmixed_train_reduced = np.array(X_xmap_unmixed_train_reduced).T[0]
X_xmap_unmixed_train_reduced[X_xmap_unmixed_train_reduced<0]=0
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[153], line 40
#      37 unmixed_xmap_X_train_reduced = np.array(unmixed_xmap_X_train_reduced).T[0]
#      38 unmixed_xmap_X_train_reduced[unmixed_xmap_X_train_reduced<0]=0
# ---> 40 unmixed_xmap_X_test_reduced = [np.mean([CCM.PairwiseCCM().compute(unmixed_test_all_concat[[i]],observables_test[:,:X.shape[1]].T[:,:,None],1200,600,60,0,method="simplex",).mean(axis=0) for exp in range(5)] ,axis=0) for i in barycenter_vars]
#      41 unmixed_xmap_X_test_reduced = np.array(unmixed_xmap_X_test_reduced).T[0]
#      42 unmixed_xmap_X_test_reduced[unmixed_xmap_X_test_reduced<0]=0
#
# File ~/Documents/Python projects/FastCCM/src/FastCCM/CCM.py:85, in PairwiseCCM.compute(self, X, Y, subset_size, subsample_size, exclusion_rad, tp, method, **kwargs)
#      82 Y_sample_shifted = self.__get_random_sample(Y, min_len, smpl_indices + tp, num_ts_Y, max_E_Y)
#      84 if method == "simplex":
# ---> 85     r_AB = self.__simplex_prediction(lib_indices, smpl_indices, X_lib, X_sample, Y_lib_shifted, Y_sample_shifted, exclusion_rad, nbrs_num)
#      86 elif method == "smap":
#      87     r_AB = self.__smap_prediction(lib_indices, smpl_indices, X_lib, X_sample, Y_lib_shifted, Y_sample_shifted, exclusion_rad, theta)
#
# File ~/Documents/Python projects/FastCCM/src/FastCCM/CCM.py:171, in PairwiseCCM.__simplex_prediction(self, lib_indices, smpl_indices, X_lib, X_sample, Y_lib_shifted, Y_sample_shifted, exclusion_rad, nbrs_num, return_pred)
#     167 nbrs_num_max = nbrs_num.max().item()
#     168 #nbrs_mask = (torch.arange(nbrs_num_max).unsqueeze(0) < nbrs_num.unsqueeze(1))
#     169
#     170 # Find indices of a neighbors of X_sample among X_lib
# --> 171 weights, indices = self.__get_nbrs_indices_with_weights(X_lib, X_sample, nbrs_num, nbrs_num_max, lib_indices, smpl_indices, exclusion_rad)
#     172 # Reshaping for comfortable usage
#     173 I = indices.reshape(num_ts_X,-1).T
#
# File ~/Documents/Python projects/FastCCM/src/FastCCM/CCM.py:286, in PairwiseCCM.__get_nbrs_indices_with_weights(self, lib, sample, n_nbrs, n_nbrs_max, lib_idx, sample_idx, exclusion_rad)
#     284 dist = torch.cdist(sample, lib)
#     285 # Find N + 2*excl_rad neighbors
# --> 286 near_dist, indices = torch.topk(dist, 1 + n_nbrs_max + 2 * exclusion_rad, largest=False)
#     288 if exclusion_rad > 0:
#     289     # Mask out neighbors within the exclusion radius
#     290     mask = ~((lib_idx[indices] < (sample_idx[:, None] + exclusion_rad)) &
#     291             (lib_idx[indices] > (sample_idx[:, None] - exclusion_rad)))
#
# RuntimeError: selected index k out of range

# %%
import umap
reducer = umap.UMAP(metric='precomputed', n_neighbors=25, min_dist=0.1, n_components=2, random_state=10)
X_umap = reducer.fit_transform(2-(ccm_unmixed_train+ccm_unmixed_train.T))
# Out:
# /home/iaroslav/miniconda3/lib/python3.12/site-packages/umap/umap_.py:1858: UserWarning: using precomputed metric; inverse_transform will be unavailable
#   warn("using precomputed metric; inverse_transform will be unavailable")
# /home/iaroslav/miniconda3/lib/python3.12/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
colors = np.array([
    [0.894118, 0.101961, 0.109804],  # Red
    [0.215686, 0.494118, 0.721569],  # Blue
    [0.301961, 0.686275, 0.290196],  # Green
    [0.596078, 0.305882, 0.639216],  # Purple
    [1.000000, 0.498039, 0.000000],  # Orange
    [0.500000, 0.500000, 0.500000],
    [0.596078, 0.305882, 0.639216],  # Purple
    [1.000000, 0.498039, 1.000000],  # Orange
])
# Create subplots with 2 columns
fig, axes = plt.subplots(1, 2, figsize=(13, 6),dpi=150)  # (1 row, 2 columns)

# Plot the first subplot (matshow)
im = axes[0].matshow(ccm_unmixed_train_reduced, vmax=1, vmin=0)
axes[0].set_title("CCM Matrix")
axes[0].set_xlabel("Cluster")
axes[0].set_ylabel("Cluster")

# Add colorbar for the left subplot
cbar = plt.colorbar(im, ax=axes[0], fraction=0.03, pad=0.09,orientation="horizontal")
cbar.set_label("CCM Rho",)

# Plot the second subplot (scatter and arrows)
scatter_ax = axes[1]
scatter = scatter_ax.scatter(
    X_umap[:, 0], X_umap[:, 1],
    c=[colors[i] for i in col_clusters],
    s=150
)
scatter_ax.set_title("UMAP Projection of CCM Matrix Between\nLearned Components")

# Add a custom legend
cluster_labels = ["Clust. 0", "Clust. 1", "Clust. 2", "Clust. 3", "Clust. 4", "Clust. 5"]
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[i], markersize=10, label=label)
           for i, label in enumerate(cluster_labels)]
scatter_ax.legend(handles=handles)
scatter_ax.set_xlabel("UMAP 1")
scatter_ax.set_ylabel("UMAP 2")

# Call the custom function for arrows
plot_pairwise_arrows_with_direction_gradient(
    scatter_ax,
    (ccm_unmixed_train_reduced.T - ccm_unmixed_train_reduced) > 0.1,
    ccm_unmixed_train_reduced.T,
    X_umap[barycenter_vars]
)

# Adjust layout for better appearance
plt.tight_layout()
# Show the plots
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming `unmixed_train_all_concat` is your dataset and `barycenter_vars` contains your variable names
fig, axes = plt.subplots(len(barycenter_vars), 1, figsize=(10, 8), dpi=150,sharex=True)

for i, var in enumerate(barycenter_vars):
    axes[i].plot(unmixed_train_all_concat[var][:, 0], color="black")
    
    # Add a label on the left indicating the variable
    axes[i].set_ylabel(f"Cluster {i}\nvariable", fontsize=12, labelpad=5)
    axes[i].yaxis.set_label_position("left")
    axes[i].tick_params(axis="y", which="both", left=False, labelleft=False)  # Remove tick marks on y-axis

    # Remove borders
    axes[i].spines["top"].set_visible(False)
    axes[i].spines["right"].set_visible(False)
    axes[i].spines["left"].set_visible(False)
    
    # Add a grid for clarity
    axes[i].grid(axis="y", linestyle="--", alpha=0.7)

# Label the shared x-axis
axes[-1].set_xlabel("Timestep", fontsize=14)

axes[0].set_title("Dynamics of Representative Variables",fontsize=16)
# Adjust spacing for compactness
plt.subplots_adjust(hspace=0.4)  # Space between subplots
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming `unmixed_train_all_concat` is your dataset and `barycenter_vars` contains your variable names
fig, axes = plt.subplots(len(barycenter_vars), 1, figsize=(10, 12), sharex=True)

for i, var in enumerate(barycenter_vars):
    axes[i].plot(unmixed_train_all_concat[var][:, 0], color="black")
    axes[i].set_title(f"Cluster {i + 1} variable dynamics", fontsize=10)
    axes[i].grid(True)

# Adding labels for shared x-axis
axes[-1].set_xlabel("Time", fontsize=12)

# Adjust spacing between subplots for better readability
plt.tight_layout()
plt.show()

# %%
plt.plot(unmixed_train_all_concat[barycenter_vars[0]][:,0],color="black")

# %%
bx = np.linspace(0, 1, 100)
by = np.linspace(1, 0, 100)
gradient = np.outer(by,bx)  

fig, ax = plt.subplots(figsize=(8, 6))

ax.imshow(gradient, extent=[0, 1, 0, 1], origin='lower', aspect='auto', cmap='plasma')

ax.plot([0, 1], [0, 1], color="black", lw=3)
ax.scatter(ccm_unmixed_train[:,barycenter_vars[0]],ccm_unmixed_train[barycenter_vars[0]],c="white",zorder=2)

# %%
density = np.sort(ccm_unmixed_train+ccm_unmixed_train.T,axis=1)[:,-20:-1].mean(axis=1)/2

# %%
def compute_perplexities_from_similarity(sim_matrix):
    """
    Compute the perplexity for each point using a similarity matrix.
    
    Parameters:
        sim_matrix (np.ndarray): A 2D array of shape (n, n) representing the pairwise similarities.
                                 If using a correlation matrix with values in [-1, 1],
                                 this function will convert it to the [0, 1] range.
    
    Returns:
        np.ndarray: A 1D array of perplexity values for each point.
    """
    n = sim_matrix.shape[0]
    perplexities = np.zeros(n)
    
    # If sim_matrix is a correlation matrix (with values between -1 and 1),
    # transform it to [0, 1] where 0 means no similarity and 1 means perfect similarity.
    S = (sim_matrix + 1) / 2
    
    # Compute the probability distribution for each point and its entropy
    for i in range(n):
        # Copy the similarity row for point i and set self-similarity to zero
        S_i = S[i].copy()
        S_i[i] = 0.0
        
        # Normalize to obtain a probability distribution over neighbors
        sum_S = np.sum(S_i)
        if sum_S == 0:
            probabilities = np.zeros(n)
        else:
            probabilities = S_i / sum_S
        
        # Compute the Shannon entropy of the distribution.
        # A tiny constant is added to avoid issues with log(0).
        H = -np.sum(probabilities * np.log(probabilities + 1e-12))
        
        # Perplexity is defined as the exponential of the entropy.
        perplexities[i] = np.exp(H)
    
    return perplexities

# Example usage:
# Suppose you have a 5x5 pairwise distance matrix D and a corresponding sigma vector.
D = (ccm_unmixed_train+ccm_unmixed_train.T)/2

perplexities = compute_perplexities_from_similarity(D)

# %%
plt.figure(figsize=(6,5),dpi=150)
plt.grid()
plt.scatter(X_umap[:, 0], X_umap[:, 1],c=perplexities, cmap='viridis', s=150)
plt.colorbar(fraction=0.03, pad=0.09,label="Point Density")
plt.title("UMAP Projection of CCM Matrix Between\nLearned Components")
plt.xlabel("UMAP 1")
plt.ylabel("UMAP 2")
# Out:
# Text(0, 0.5, 'UMAP 2')

# %%
plt.scatter(X_umap[:, 0], X_umap[:, 1],c=(CCM.PairwiseCCM().compute(unmixed_train_all_concat,
PCA(10).fit_transform(observables_train[:,:62]).T[:,:,None],1500,600,60,0,method="simplex",nbrs_num=10,).mean(axis=0))[0], cmap='viridis', s=150,vmin=0,vmax=1)

# %%
# Plot the results
#plt.scatter(X_umap[:, 0], X_umap[:, 1],c=np.repeat([1,2,3,4,5,6,7,8],np.array([1,2,3,4,5,6,7,8])*6), cmap='viridis', s=50)

plt.scatter(X_umap[:, 0], X_umap[:, 1],c=ccm_unmixed_train[-5], cmap='viridis', s=150,vmax=1,vmin=0)
plt.show()
plt.scatter(X_umap[:, 0], X_umap[:, 1],c=unmixed_xmap_X_test[19], cmap='viridis', s=150,vmax=1,vmin=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 6
#       4 plt.scatter(X_umap[:, 0], X_umap[:, 1],c=ccm_unmixed_train[-5], cmap='viridis', s=150,vmax=1,vmin=0)
#       5 plt.show()
# ----> 6 plt.scatter(X_umap[:, 0], X_umap[:, 1],c=unmixed_xmap_X_test[19], cmap='viridis', s=150,vmax=1,vmin=0)
#
# NameError: name 'unmixed_xmap_X_test' is not defined

# %%
plt.scatter(X_umap[:, 0], X_umap[:, 1],c=np.repeat(n_comp_list,np.array(n_comp_list)*9), cmap='plasma', s=30 * np.repeat(n_comp_list,np.array(n_comp_list)*9)[::-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 plt.scatter(X_umap[:, 0], X_umap[:, 1],c=np.repeat(n_comp_list,np.array(n_comp_list)*9), cmap='plasma', s=30 * np.repeat(n_comp_list,np.array(n_comp_list)*9)[::-1])
#
# NameError: name 'n_comp_list' is not defined

# %%
plt.plot(unmixed_train_all_concat[col_clusters==5][:,:,0].T)
plt.plot(unmixed_train_all_concat[barycenter_vars[5]][:,0],color="black")

# %%
plt.plot(unmixed_train_all_concat[barycenter_vars[0]][:,0],unmixed_train_all_concat[barycenter_vars[4]][:,0],)

# %%
plt.plot(unmixed_train_all_concat[barycenter_vars[0]][:,1],unmixed_train_all_concat[barycenter_vars[0]][:,4],)

# %%
from sklearn.metrics import pairwise_distances
plt.matshow(pairwise_distances(unmixed_xmap_X_test_reduced))

# %%
plt.matshow(np.corrcoef(unmixed_xmap_X_train_reduced.T))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 8), dpi=150)

# Display the matrix
plt.imshow(
    unmixed_xmap_X_train_reduced,
    vmin=0,
    vmax=1,
    aspect="auto",
    interpolation="nearest",
    cmap="viridis",  # Optional: Use a perceptually uniform colormap
)
# Add a colorbar with appropriate padding and label
plt.colorbar(fraction=0.03, pad=0.04, label="CCM Rho")

# Add axis labels and title
plt.ylabel("Neurons", fontsize=12)
plt.xlabel("Clusters", fontsize=12)
plt.title("Cross-mapping Prediction of\nNeurons Using Learned Components", fontsize=14)

# Adjust layout for better readability
plt.tight_layout()

plt.show()

plt.figure(figsize=(6,10))

plt.imshow(unmixed_xmap_X_test_reduced,vmin=0,vmax=1,aspect="auto",interpolation="nearest")

# %%
plt.figure(figsize=(12,5))
plt.plot(observables[:,21])
plt.plot(observables[:,5]-2)
plt.plot(observables[:,19]-4)
plt.xlim(0,5000)
plt.show()

plt.figure(figsize=(12,5))
plt.plot(unmixed_train_all_concat[barycenter_vars[0]][:,0])
plt.plot(unmixed_train_all_concat[barycenter_vars[4]][:,0]-4)
plt.plot(unmixed_train_all_concat[barycenter_vars[5]][:,1]-6)
plt.xlim(0,5000)
plt.show()

# %%
plt.figure(figsize=(13,4))
plt.plot(observables_train[:,54])
plt.plot(observables_train[:,60])
plt.plot(observables_train[:,61])
plt.plot(unmixed_train_all_concat[barycenter_vars[3]][:,0])
